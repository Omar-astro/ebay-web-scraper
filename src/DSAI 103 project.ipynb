# %% [markdown]
# MAIN SEARCH

# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
from serpapi import GoogleSearch

item_search = input("what item do you want to search for: ")
web_type = 'ebay'

#EBAY-----------------------------------------
def Search_ebay(x):
    global URL, list_of_items, photos, titles, price, links, ship_price
    params = {
    "engine": "google",
    "q": 'site:ebay.com ' + x,
    "api_key": "9465d440bd4b692b0e147d4f8684399f15a7afb9891f546f33c6867cd2a71983"
}

    search = GoogleSearch(params)

    results = search.get_dict()
    nresults = results['organic_results']

    headers = {"User-Agent": "Mozilla/5.0"}


    for i in range(len(nresults)):
        if 'https://www.ebay.com/b/' in nresults[i]['link']:
            print("link to all the items:" , nresults[i]['link'])
            URL = nresults[i]['link']
            break
            
    r = requests.get(URL, headers=headers)
    print(r)
    soup = BeautifulSoup(r.content, 'html.parser')
    titles = soup.find_all('span', class_="bsig__title")
    price = soup.find_all('span', class_="textual-display bsig__price bsig__price--displayprice")
    templinks = soup.find_all(class_='bsig__title') 
    links = []
    for title in templinks:
        link_tag = title.find("a")
        links.append(link_tag['href'])
    photos = soup.find_all('img', class_="brwrvr__item-card__image")
    ship_price = soup.find_all('span', class_="textual-display bsig__generic bsig__logisticsCost")
    #print(len(titles),len(price) ,len(links), len(photos), len(ship_price))        

    list_of_items = []
    for i in range(len(titles) if len(titles) < len(ship_price) else len(ship_price)):      #if faced with error here it can be due to the length of things found can be different, search for another item.
        item_stuff = [i, price[i].get_text(strip=True), titles[i].get_text(strip=True), links[i], photos[i]['data-originalsrc'], ship_price[i].get_text(strip=True).replace(' shipping', '')]
        list_of_items.append(item_stuff)
    
    for i in range(len(list_of_items)):
        print(list_of_items[i])

print(item_search)
Search_ebay(item_search)
# Out:
# glasses
# link to all the items: https://www.ebay.com/b/Prescription-Glasses/179693/bn_2313852
# <Response [200]>
# [0, '$150.61', '"SWAROVSKI" CRYSTAL EYEWEAR EYEGLASSES FRAMES GLASSES EYEGLASSES HALF FRAME', 'https://www.ebay.com/itm/396477498253?hash=item5c4fe6838d:g:UFkAAOSwnNBXbZLW&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lxlXnaZjd7ReA2hG%2FQpaBnm7KE%2FyUrTA5TjPIECADVZnYTK0CtdKl4Lxo4HLo%2BpBgbqJysUiA%2F866g1dzl5%2FTKN0SBJJV4z2YUxQ3iOz5p7%2FioWb35jHKpKTKDJ3nw7ShdvGavDuMFGePAUde0zFHNP84mfaApbTBr%2B0dfWxKHfZPTIydFIaJb0VTaNdnhBdAGGDtpclJCx8Oe7u3PeYlrKMygIcX6dHJ1foosFenla7rftUT6X4CcUfaFixyrKI19v1UFTl0SaDj8b%2FcBtSli%7Ctkp%3ABFBM4o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/UFkAAOSwnNBXbZLW/s-l400.jpg', '$52.54']
# [1, '$39.70', 'Gianfranco Ferre GF Eyeglasses 40017352 Worldwide Post 40017352', 'https://www.ebay.com/itm/256661166529?hash=item3bc23299c1:g:oeQAAOSwO3ZmHOQg&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mClIRXNLHbSrgnRQz3UlAgOclKLBERtQTTf1M4kapva%2FMIfI--DSIgwesP5NG4mg1PbFQVxsiQF1yzQxCG7kF3Z5iMcOjihmw%2FgXZ9bno8uYJK5e61putV%2Fe732MYrHTPfZn4sTNNIR0IXG%2FGTYZshDEaQPDKVvyc2ltPyd2TkNaGxLxMqM7UUk8Vw6z%2BfRk%2Fa1d0xPJkuzUwzul94EqhBHieu%2FmLrwDHuu9O0g0tEx540Fy0aWYbelSfa7hoKS50VkA9HqdfRcs%2F6i0PYrNae%7Ctkp%3ABFBM5I3HwZRm', 'https://i.ebayimg.com/images/g/b2kAAOSwjXRXbZLP/s-l225.jpg', '$3.50']
# [2, '$150.61', 'ST.DUPONT LUNETTE CARBON EYEGLASSES GLASSES FRAMES EYEGLASSES FRAME OCCHIALI', 'https://www.ebay.com/itm/326589192455?hash=item4c0a3b9907:g:0CoAAMXQhuVRMNV7&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nzwt0UC97%2F6PkNCd4jXl6cV2GlG3jSfU2r3opfjhEf6fo1xY8ZOs9t5yY3V%2FJlaoIASF5D1tiPmbrJsre%2Bu7HK1vm7BC%2FK38qMn9oW35nIWzFdnFtwVKh4YlU0FBDWMRaDyR82PzmESJhi3t5lMec%2Bzn1IdhCIex7KeBg9NvMi82vLmuRVtpCzRFJntwtv0AjQzdxcdfwoAtJyBEd1gVfks5Lhdu5%2FPTuYnpKZCZJNurF%2F2T1NSrRqPu0XkPuuWqwIfM6qpuD7G0l0y4QNkyf6%7Ctkp%3ABFBM5I3HwZRm', 'https://i.ebayimg.com/images/g/WWkAAOSwc1FXbZLQ/s-l225.jpg', '$52.54']
# [3, '$185.63', 'ST.DUPONT EYEGLASSES FRAMES EYE-GLASSES FRAME OCCHIALI LUNETTE TITANIUM ОЧКИ', 'https://www.ebay.com/itm/391645314350?epid=634236421&hash=item5b2fe13d2e:g:3v8AAMXQNbxRfeb8&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30kssGCysbjBvGQc3zCyzZBl5TuD24mcNmTr3arr2DFxBSyHQ5B0xwVz%2BtAJVGpMwVMDCO6JaEeMk3arKYUf%2BHPG4FA5jmhTFAVnCL%2FgmED%2FtxeQgc663mXBaOmB8e3BPr5MSaha5o3%2BcY8Aq%2B5OWHv%2Fan2iqoyXri78VmOCpBVCRil%2BB2NVWLfgVibjOnXi9OvkT3NqnNCOea2xjPfYnCAJY%2Bya85%2B4K%2BoYw5GrneLRgE26nHIRfO3tSTqyslRIL0CuVfHOAT2bXtFjkIxfApyA%7Ctkp%3ABFBM5I3HwZRm', 'https://i.ebayimg.com/images/g/-vwAAOSwvg9XbZLR/s-l225.jpg', '$52.54']
# [4, '$577.91', 'CARTIER SIGNATURE -C-DECOR LUNETTES EYEGLASSES FRAMES GOLD FINISH EYEGLASSES', 'https://www.ebay.com/itm/326329614814?hash=item4bfac2c1de:g:R4kAAOSwSGVnK9dS&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nS%2BoHgjxodxUqV73aaNGKUtei4AupA7oslY3%2FKZQqYfenD8h9hKczDbj7Yd5fLDVfDo386pZx6oBlhwZKiZwlOHzQYOBile3fE08mWztxtfEaduZyQFiBNSNwFY2DrLn0NMEAG%2FH7fnXRjsCuEHbZ5Nvh73iBpHk1uqdlRn5avC65ySMfFakpBg%2BlR1t6I6IKgjo%2B2lf7AE7taim8np9C2ZLiIWEcPDSfFNHePlYswdzaNYvQjbIqC1nrIR9bOxbnFO%2FmkEuXy34J%2FWLxIJBrV%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/oeQAAOSwO3ZmHOQg/s-l400.jpg', '$57.21']
# [5, '$1,745.41', 'VINTAGE CARTIER EXCEPTION C-DECOR PRECIOUS WOOD RIMLESS GLASSES BUBINGA WOOD RARE', 'https://www.ebay.com/itm/326312746808?hash=item4bf9c15f38:g:9g4AAOSwbu5nGBwu&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30k3j4PHqoDCrcbXjT73zeojU4srS5sUBuRYyGPBDdgFhtg4q6rlH9lcsSGwOE7aEhYxFIYdbPo6Hlo6sBeCcb6UdLdhab8JP%2FQfN%2FXjgHwmAkEMHSJh8oUQ2R4X1NgNYT%2BiuxWzt8aK%2FQ3w0%2FhP8ZjNDBZiRCpLycxW%2FQhrlKPPSSVcaF%2Fi0XOZIVoibxdIUsvx6qQyDdMd4MiOf3QfJGyPxKJVkbuyiCz8RkQRFMlVjuRYvFte%2FrZMniN5XIuY49bhFiyTEgVDuy9a7z3pvmIV%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/images/g/7LsAAOSwfoNmHOQH/s-l225.jpg', '$57.21']
# [6, '$208.98', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASS FRAME GLASSES RARE', 'https://www.ebay.com/itm/394772116761?hash=item5bea407519:g:aMIAAOSw7ehXTcJ6&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mHhim2OLlh1LRqzESFDsqVzLdZOr8tWGP%2FuAQlDDwWYRxK6S0JJpunhwf8kS%2Bzv5D84enhTwFCNJ%2FF%2Fq2IU5rZaNloRktg6NYiGm4E3rnJi9lY5eiR02j4U88DUfValSxL9uu%2FDQWUiFrpl9ktb%2FTGjL5R3IH3tXKk22uTu8ri7lC5RL6rXlMZ5YPUoHeVFZDgOQTB4xp%2F0dbFsozjpaK8puqv%2FjFdSks9s2eesCWebh6qRHUEtWCYtcqQbj7ypDFby5QheVkm%2B10uCzdtdhdJ%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/images/g/SXwAAOSwtfpmHOQO/s-l225.jpg', '$52.54']
# [7, '$221.71', 'Cateye Eyeglasses Large Silhouette Lightweight Plastic SPX Womens Black Green Purple Sz L', 'https://www.ebay.com/itm/376468642449?hash=item57a7479a91:g:dOkAAOSwYXVYy8EM&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30k3By%2BHs%2BC%2FfbR7Nz5TxiFHyymnb9rq18MOcJg7d69vW%2B2a4xEpW2Z3YiZAtw5mMnB8tsxgNoGMrhHngeLzVdJeWcVlnCQliDG2N8oYbjdl8eg2lYCkR%2Bn6zlgDAe0MP4ytTgPZCIMa0SOZCmWsmtXpxUh54iFwYoh5yvvBNr%2Fccem1ii3O5Lx2OjRiMz%2Fg%2B0qHlWgNxQFDGbpS4hhAeaIxH%2Bk43rQL3y2hGki38WhHnbOeQRRMVbNJ7G05djM6Ku5wYfbq5cWetFNFDxZHXpBc%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/images/g/6t4AAOSw5eNmHORS/s-l225.jpg', '$16.23']
# [8, '$58.26', "Men's Eyeglasses Frames Sporty Pilot Shape Double Bridge Gold Tone Cheap Size M", 'https://www.ebay.com/itm/396945152451?hash=item5c6bc659c3:g:mb0AAOSwLdhkmrj0&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30kwx%2BY4ir5vHG93Iygfg%2FPAL04ihXTgujq9gnMHpxb80VS2UZWN5CkkXT5Us9aA%2FScawt58NtLgBdTEplYJFexHgtRF8%2FQKiGHps1Rk%2Bhjz2nPEC57wJDJiHUib0z1YMsaGdWVXFzUPEjFZFntFyzjQrPFW0btF6FKPoNDy9ZURNDe%2FzUt9QX0JCE0iFeHMZl9rLQFPWzgaMXvxerpDyE%2BDEnHHPlgKnSP%2FMLd%2ByBSBd3mzid%2FGN%2Bj3ZIA59lTO86SXGDhj0N2V8r2Z41vcGlNh%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/0CoAAMXQhuVRMNV7/s-l400.jpg', '$17.40']
# [9, '$208.98', 'ST.DUPONT TITANIUM EYEGLASSES FRAMES EYE GLASSES FRAME OCCHIALI LUNETTE ОЧКИ', 'https://www.ebay.com/itm/391492004862?hash=item5b26bdebfe:g:oCsAAOSwxYxUv8X~&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lOH6qa09z3t%2F3has4sExlaihpYpu6nPCkr%2BebbFoB2xNp%2BXdos%2BVTUUELKOrPIxxUU7Y0aoJxyAn0t26lQ9gMCG6ms%2FZciYiSDL0PCEBfPOcIjfi3bQjPg61MfyLq7x2wsKMFFX4vd8bmLqbzCg35i2AmqbXdbMxhn3pA7C8SJ44CQiH3Qnj5oVHVlrNhlmtf59%2BeMXS1nr1xI0q5v1aHZ9BPhQQ2ZKH7mnVaVsieFWHQA5TnbL0yDkZp%2BYxhokxOWh5C9%2BGV2wWDcnyPOajmR%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/images/g/x-0AAOSwNuxXXyyn/s-l225.jpg', '$52.54']
# [10, '$185.63', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASS FRAME GLASSES RARE', 'https://www.ebay.com/p/656178274?iid=320982976636', 'https://i.ebayimg.com/images/g/2M0AAOSwMNxXXyyo/s-l225.jpg', '$52.54']
# [11, '$15.35to$32.68', 'Myopia Nearsighted Photochromatic Self-Tinting Glasses 0 to -4.0 DHL Shipping', 'https://www.ebay.com/itm/176634835771?hash=item292041b33b:g:YgkAAOSwhABm50eN&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30lwy%2Bf6taR0RPr9YG3eQ0eOmhw7VP%2FtW45WrHtBDHT0FCs7ms07lfg8lAO3ew7nLjZrcuPWYV6Oy0BQs8SLXkGrmFXz%2FJHSm6XWbrPSdbcX33osB%2B2Ud8QpSDiZ%2F6ObNbS2j6fQ1TjeMRiaFouJIGhQpsNGmCpn8%2F4WIhroUwn7blc5fKwRWYOQqSUDB5oE5%2BrfPXUliR2jaipki8BVE9kjv3NX%2FgUfwHj5cv%2BCuW0Ang%3D%3D%7Ctkp%3ABk9SR-SNx8GUZg&var=476285495276', 'https://i.ebayimg.com/images/g/x0MAAOSwOVpXXyyp/s-l225.jpg', '$4.66']
# [12, '$46.58', '1 pair original glasses +1.00 DPT for Porsche Design 8801 +1.0 incl. Allen look', 'https://www.ebay.com/itm/164308859548?hash=item2641923a9c:g:wzsAAOSwoupaqjAm&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30nM1F87S%2FtM8SVFXUqvGzhhQu4dTRSSgQOKtoh86mHbPIIHwM7ZrT%2B1j0bDp1vbnvaWXVC6gG6yacK%2BpT4ANrcHc%2BbW9PqXTrxQDPRNaDaJe50Tf48TjOw3NGSeVo5EyPJFkBr1HT0ucTvopkMajIgY6MxxLajhKmHKwEeLOpC1vDD1Z8r%2FTYs8gP3KXzHZbDGyqJjcqLD9h9I7h%2BOrspzZHAjDeG3SK%2BKu5DVZMKHwFQ%3D%3D%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/3v8AAMXQNbxRfeb8/s-l400.jpg', '$46.58']
# [13, '$220.66', 'ST.DUPONT TITANIUM LUNETTE EYEGLASSES FRAME OCCHIALI TITANIUM & GOLD FINISH', 'https://www.ebay.com/itm/325268487357?hash=item4bbb833cbd:g:EMQAAOSw3ihXTcJ0&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nWyFIsBpj%2B23KWgtFNbworQfEtLfU8SoCXEvAUskKp8P97KVT0KQhk1A6JiTNWkZSsy8hJImRRYDI2g%2BMV8PPxGt82nMUvUJwQLMR57i22lkFTTt6WEUc2pvj5x2fj5UTJp6X1kgHN03f%2FbwZtLxlZw1n0wv%2FdCjosINRL7UEUavQzJA%2FLcT8Hfy3LzaPzJ0QJFCL%2BdWeuYtwItFYcv4Z1A8KRAPjZQb490K1pa1MS%2Bw%2BQlIQ%2FnCu66QG20%2FisDe9He3907b2d7J3zLkWdU1Xt%7Ctkp%3ABFBM5I3HwZRm', 'https://i.ebayimg.com/images/g/JE8AAOSwbYZXdZX0/s-l225.jpg', '$52.54']
# [14, '$185.63', 'S.T.DUPONT TITANIUM GLASSES EYEGLASS FRAME BEZEL GLASSES NEW', 'https://www.ebay.com/itm/394785143480?hash=item5beb073ab8:g:95cAAOSw9mFWMNj4&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mpr0dXG4Jz8fEWQZQBpr1fyNAoL3ZViFf2LwdnKPo4OAlHItnIiLAB1xdKA1Geja5sx5SPqOpntOA8MQx%2FhswHBcUtrQINyIdegoSJqGYqiveOXA9k1kfrVV7HgTv%2Fv%2F4gXNAFMF%2FEqNlRs74UkeT5ZUgp2cMnTvjaJKmeSWgEOuAHrZTl4YPJFEPojNvs10DUyk9dTlmZ%2F38QKn5wOGJtFp4B%2BQfGBiDkbXKyaL7njNUrifbfXYHwrYCWwOT3ayt%2FWMuDc1XRKZEAN2AjXAIg%7Ctkp%3ABFBM5I3HwZRm', 'https://i.ebayimg.com/images/g/TrkAAOSweWVXdZX0/s-l225.jpg', '$52.54']
# [15, '$185.63', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASS SOCKET HALF FRAME GLASSES', 'https://www.ebay.com/itm/322134498610?epid=634236421&hash=item4b00b65d32:g:NFsAAMXQHDlRfKSR&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lU3MYaLPc%2Ff7xRU3WbYZvFi3PTWEPrP%2BP8QsX25BNWT3DYGudUtVncx7rhkntl5w2T6dOAQSS8I0X7etCDreE4kUAzMAZCuYxY0c2HVmgF6%2F7cxpbs15%2BrMCrU4mrHBUWH8QETwlJgJOkALfLquTzaamlCs9JLol8Oa1%2FNrWAd2wzgSJ2vuQ8yOOFOtFHz7s%2BIIvcwhR6DWI3UBn9FgvTrMNzg3tseWmAkyQpTAKryWgUNnekaw4B08utvosOwKmSaQZAui5l4jHcIt%2FjeIlKd%7Ctkp%3ABFBM5I3HwZRm', 'https://i.ebayimg.com/images/g/TakAAOSwRQlXdZX1/s-l225.jpg', '$52.54']
# [16, '$162.28', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASS FRAME GLASSES RARE', 'https://www.ebay.com/itm/322298155123?hash=item4b0a779073:g:94AAAOxybi9RfPgr&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30njZdyjXCW3DTyAuQPhDbMIlXCru2E%2B7GKVOhBbWvGl7Zs6G065iyQH1v%2BLsqSGZpKqZeP%2BZ3TJ3QddPEqprGPIfop5seDXuNQ3M8l5WvOByoX6zOFOUVp5wieXqx8sV7OfNRvaedgcIYCZVlMZTxdj8LstCWyfSkOp6iWyEijPfnlrWS1btVha84wLW3PuDCW89Cn8hEJt4FrW%2FDQWC7%2B5hXY%2BP0GehKHJnssEhWxaVA%3D%3D%7Ctkp%3ABk9SR-SNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/R4kAAOSwSGVnK9dS/s-l400.jpg', '$52.54']
# [17, '$256.84', 'Eyeglasses CHANEL CH2189J-C396 52/19/135mm Made in Italy', 'https://www.ebay.com/itm/126862876370?hash=item1d899dded2:g:Nw8AAOSwYQZndn4u&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lVlRwtumxzHDbdMC3L0yobbi4gGDBinw2yhYQbZWzEpxaP41FZazOgyrwBWeofr9wWVdN8aHtcSFdyHt4g5I6HNFhJ6Plgu1o%2BPM7hILDqsZ%2FN6xcAPAA7cdtk1K61ToU7CWCqRON7mlp6KofixP2UOkcZhWP%2FRRH70yxL5lHVaIDDD5A0n3Xw41gch03MhpufOwbsk0BRey5c%2Bo1WYBy%2B%2BHGZY7tUEw%2FwpWO73TJMiTGUByCKnJXTBUhbCi4KtPrHW0nfTbxXKAmtwasamsp4%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/9g4AAOSwbu5nGBwu/s-l400.jpg', '$40.86']
# [18, '$185.63', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASSES FRAME EYEGLASSES EYE GLASSES ОЧКИ', 'https://www.ebay.com/itm/391492110555?hash=item5b26bf88db:g:NnsAAOSwAYtWMNj7&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30kiHZ69fwEFwknizpfCuUJFG%2BI4N1aPW2OehL42%2FVKTH8snbD2kH1pTArcpw%2BwbVaduQyPr%2FSeo3%2BizxXfhb7opVxrHwxN%2B2SgojIlH6iWQqIw56nITjhxL443I4K5gsIdlejwoej9yAKAB8atgsRAvHPqeK5lSxy1kIa0ay6VHwdAgkdJUmBz6aZWDDfv2sSg5%2FyJJKToO8Jk72fxryuqH4BLP40Mc14mfirBZ%2BLBeqA%3D%3D%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/aMIAAOSw7ehXTcJ6/s-l400.jpg', '$52.54']
# [19, '$208.98', 'ST.DUPONT AVANCE LUNETTE EYEGLASSES FRAMES GLASSES EYEGLASSES FRAME OCCHIALI', 'https://www.ebay.com/itm/391966831714?hash=item5b430b3462:g:y3QAAOSwLfxg-Aub&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30kduqAOK%2FJ%2FzKzWTMKVn%2FVwVYTHVNz2ovZY%2B1fUfUnVIgvOEdxPFKiPJx01WVFbNOx5vDba7kWeTuW%2B%2F4NwJbIx7KsSwUDkQii5CcUUv0uuA9zK8PSKdPONEgzhou%2BtzXYtxrwi%2BUn91MW4UG1gSDz%2FOmqYT%2Bpfap1O8MAJive71unyEhCSHzTr%2B5UZHqFtcpD8c%2FZKe1ElMSZ4e%2BDTpK1ddmdmXQ%2Ffrg1cnccpDpdblOC%2BNWpTWszcKa6PGr2H4MqUVFqaw4gbJ9NQedZsAFId%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/dOkAAOSwYXVYy8EM/s-l400.jpg', '$52.54']
# [20, '$151.76', 'Ermenegildo Zegna EZ 0003 57/15/140mm B90 Dark Blue Sunglasses Made in Italy', 'https://www.ebay.com/itm/116462001068?hash=item1b1dad1bac:g:FI4AAOSwynVnm5KW&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30kQqCPMzBytLPuZvYOSg%2BcmKQnTTqPj5dN9b58I1%2B6O0i3PZzoaVuZS11UMz5pZWwSVN7gqZfY0RVzD9zkDCAa8lstMV8YpqvizY0krT97jTUswMhNZMA3sB53nkvzNbxP1SaWkt3IUgBgyXOMOqVlX7DnzQokI37WYWKFiZsOPkJnnJf9SXOlBUhwpgZaMMD7ScQXocH7X39QxOTbIPVZGcJ7KxeDnRVvZC84I0rAEAQ%3D%3D%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/mb0AAOSwLdhkmrj0/s-l400.jpg', '$40.86']
# [21, '$185.63', 'S.T. DUPONT GLASSES GLASSES HALFFRAME EYE-GLASSES FRAME GLASSES GLASSES', 'https://www.ebay.com/itm/325751999416?hash=item4bd8550bb8:g:s6cAAOxyuCJRc45c&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30nsYTh52E0oghUhyJjc8L4qzWVuoTg2l8DeyGKqUugSyNlALsEvXPx5Mzdc4uQezReUqPI%2BJrEKNRv2L2XBquV83x6IwyBfvpDPwULgTMhSQnE4TNSMkkfJmBaElR5jBisoTkmhcJrcLEXN90J3JumC%2BoDB668k8jCuBW9lTTlL0w2Hx4HH06CIQBt%2Fnt54LJdu5zMyAyClz7xuHwOfDE1IH1Pg4RdcO4m9ADrbH5MArA%3D%3D%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/oCsAAOSwxYxUv8X~/s-l400.jpg', '$52.54']
# [22, '$162.28', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASS FRAME GLASSES RARE', 'https://www.ebay.com/itm/394102244105?hash=item5bc2530309:g:jxoAAMXQHO9RfljU&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lCFR%2BPONy3w%2FBRrjI66pbG2ej3fDK%2BZBwHc%2FmIVZNtWHgGRl3mS0Nvc8BOSFWWm3Tinaz%2B59awe8gGm7bCuFjNIwy8z1QY10SsUbZEDlOOhZiIOcC0nh2q8wFJJ2Q1%2F9WVofmZseUoewSMnF5u6YF%2FkmCyDgN0KYHQz7FzrlBK7J8dlp%2FNoEVgSXBd%2Btw04pDJ0D%2F5r7zV1uA5gsr8ULMFCxmTWKd%2BjDtUnYMf8jGE73ZL2Q3Ndm1Qko6bYsWWw7kCgOydGr5lXePj%2FoJvZ%2FWg%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/FLYAAMXQlrxRdACg/s-l400.jpg', '$52.54']
# [23, '$185.63', 'ST.DUPONT TITANIUM BEUNETTE EYEGLASSES FRAMES EYE GLASSES FRAME OCCHIALI RARE', 'https://www.ebay.com/p/638812982?iid=325753499862', 'https://i.ebayimg.com/thumbs/images/g/YgkAAOSwhABm50eN/s-l400.jpg', '$52.54']
# [24, '$185.63', 'ST.DUPONT TITANIUM BEZEL SUNGLASSES GLASSES SUNGLASSES SUNGLASSES FRAME GLASSES GLASSES GLASSES GLASSES', 'https://www.ebay.com/itm/391496685923?hash=item5b27055963:g:yOsAAOxyuCJRfgRp&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30n7Fee%2FYJ2daQeopPCgAQ7X0%2F0RqfOp77r9u9EFpX5OO8iLDZmsXSfRA6VQ%2B1BCjDImSSwnB9kbwV4QpugRyyNcR94gymm3WL4b8CCOLlx4VwYrRzNeqel1Id%2FYNYJU4PuLuX4fW4DZP6QFxrbNvo5Hi6fk%2BnE23dJv8JwZZOsouFwpLUZ4Mx9i7uc121Nld50Ezr9Gl6%2FaUlmCDDB2qj6ig9ShBcy2PlnIuH5UfMnCAw%3D%3D%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/wzsAAOSwoupaqjAm/s-l400.jpg', '$52.54']
# [25, '$185.63', 'ST.DUPONT TITANIUM BEUNETTE EYEGLASSES FRAMES EYE GLASSES FRAME OCCHIALI RARE', 'https://www.ebay.com/itm/325751998781?hash=item4bd855093d:g:UAIAAMXQn11RfOT3&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mqIrOKYcXBp29Mg7OAD%2B5lWbOuoSusAtpvnheQ4Op4O8uwv%2BbzTf19TBmEah52GOdKp%2FELn%2ByU1bqt2Ry1gQqByEZ8XzwiseTFrIjk9NxuQAz6hgISE8cIsnUOL8n6dnEc7NXSgt9GiL%2FUiFINNDlqpGACt2845gQcS9Zz5e3sN3WcMT7Vae%2BaMAoL3ByWjw8J09QezuEWbv8JWZC73KpZJyMtPuapFoMM%2Ba6kbgJp5iyzfRklsNa7BNOM99biGRvKsiOmBOXjIPhrMdCmoocm%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/EMQAAOSw3ihXTcJ0/s-l400.jpg', '$52.54']
# [26, '$208.98', 'ST.DUPONT TITANIUM LUNETTE EYEGLASSES SUNGLASSES GLASSES FRAME OCCHIALI', 'https://www.ebay.com/p/722114177?iid=391475529563', 'https://i.ebayimg.com/thumbs/images/g/95cAAOSw9mFWMNj4/s-l400.jpg', '$52.54']
# [27, '$185.63', 'ST.DUPONT TITANIUM BEZEL SUNGLASSES SOCKET EYEGLASSES FRAME GLASSES GLASSES', 'https://www.ebay.com/p/638507379?iid=325754915230', 'https://i.ebayimg.com/thumbs/images/g/NFsAAMXQHDlRfKSR/s-l400.jpg', '$52.54']
# [28, '$43.20', 'Love Moschino Black & Cream Eyeglasses LM 13 30548305 Worldwide Post 40017352', 'https://www.ebay.com/itm/256638933552?hash=item3bc0df5a30:g:Am4AAOSwJn1mHOY8&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nEHJcxpt8hkDmeJ5W%2BJ4WxyKS8ZnTcKFIioy%2FdYrDd4QQd3NIqM8iuKr1vYl8bFIGxrniZ2vTCyqzObYOy5Zxm5hCjtcNE14KZnfGplvmLzWcyTRPtUcPYKQKN0P9T9jHoeghP7lCTp0SRu7v8BiSGWZL1Teox3zc8rDpovlGK0KT3OoSO1tkRJMLy3MG4NHR8YgPgQQ8TOZMEpZRyt6nVZR0E1U7pSOX4TKRpRwMNgesBuygPQxnQmSx2CwNSZJS%2BaCshc6gbp5UuswXwdZ3Y%7Ctkp%3ABFBM5o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/94AAAOxybi9RfPgr/s-l400.jpg', '$3.50']
# [29, '$40.86', 'Love Moschino Black & Cream Eyeglasses LM 13 30548305 Worldwide Post 40017352 Free E', 'https://www.ebay.com/itm/256627332702?hash=item3bc02e565e:g:Am4AAOSwJn1mHOY8&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nMLCAPDq9w%2BnpCiCoqwAU72K1xnudZtz4EN3eLyykG28mk51LF%2BOVTD5VHqSGbZxVF3bH4APJogfBsK5Pkl5WZZ8BvepOl7QIlaugS3%2BENu%2BaiRXnUOYNSjBpCN6AqT8yENVDRrWb3DngVt5CNBtd0UY5nGPdKhJyNrP%2FHw%2BaW2hhUD7w%2FvykwHxLwlLpEwMC9AvRUiB8eGIgU9xPiVDV6ZXld%2ByrcfoonJRzkv3GRFnBxH9whLh10IF%2BSh07VefW1tO8SYrAKwW7%2B7ctmRv9k%7Ctkp%3ABFBM5o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/Nw8AAOSwYQZndn4u/s-l400.jpg', '$3.50']
# [30, '$173.96', 'ST.DUPONT TITANIUM GLASSES EYEGLASSES FRAME EYEGLASSES GLASSES GLASSES BEZEL RARE', 'https://www.ebay.com/itm/394785131935?hash=item5beb070d9f:g:1HkAAMXQJ3xRfqbV&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nyTVo974QuDYjQX42qYWo7rcRCB8bF9IV5uNFC1q5Cjt%2FGFfAfTycVAyC%2BX0BDcr6T02bW9lNGa50%2Fuyh3iEwD9DQderNgHIlJ68haRMd1aGGRQlBk4%2FcmPQGljmCWLg7Qf0aITZ%2FwnAcIkAgzFZNS6545tSMr4WdFvdC%2BwU5a%2FD865dYYzvylesyYfJI0AL%2BdzTW%2BpmocU4rI%2B1YVR5YTWs6KTk1I6ymP4PJLlmEYW2JyDXaLhI1F0KnGH4qEPflVZwe2yE0McOCG1%2BU4ROg9%7Ctkp%3ABFBM5o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/NnsAAOSwAYtWMNj7/s-l400.jpg', '$52.54']
# [31, '$197.31', 'ST.DUPONT TITANIUM LUNETTE EYEGLASSES FRAMES EYE GLASSES HALF FRAME OCCHIALI', 'https://www.ebay.com/itm/391473125149?epid=634236421&hash=item5b259dd71d:g:ojAAAMXQwKdRbrSm&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30kgM%2BGcGED78zaWiEg9kXmI8oVyihbju63%2FvkWLyGKjwUCijZfdZ83%2BvMyIYgEL9DCQuzFbcxRWuRn3F2cztQ9MA4rMv6aHE6MXA21kW%2FP8PEUcPrtRNN6K54H7mbqPcuiVCEscKwUcVFXObVgvFBWaWPh7uWDEuIVV0I1epSR7%2FdN%2B%2B%2FhuhqWCKoD%2BEiBZvc0HAG2i9uL91uFSBk263vf3HO%2FRzw2mNL25bxiClRZLt0mcmVBqQYku66UgTds1LhKjEF%2Fo7%2BJjz6YGqjTH23Z8%7Ctkp%3ABFBM5o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/y3QAAOSwLfxg-Aub/s-l400.jpg', '$52.54']
# [32, '$210.03', 'Mikado Eyeglasses Frames Very Large 62-14 Cateye Black Fancy Eyeglasses Size L', 'https://www.ebay.com/itm/376466963981?hash=item57a72dfe0d:g:J8cAAOSwMpZUotMk&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30m3XJARpCp65ASfpW9cv4yZ9t--CrTBlI2OGRG55OCwdTxTqgfRmKZQmB8GN8FcYFKo3rzpsRRKt9Q483YLFkS5TzcYkVnKjVVdfbDMUPKQ20ljqUSOTxNlnhTVapH%2FCDF70jxnU6FvVdOnl0CodWBgZjc%2Fb%2BtBocUrIWI7ol2ctm6SDm8%2Bg1J%2FBI2PWGxjFFdngKsdeoGh4Ri89zTV5iXUnDD0Q9cg9zsF6wA%2B96XqQQ%3D%3D%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/FI4AAOSwynVnm5KW/s-l400.jpg', '$16.23']
# [33, '$145.88', 'ESCHENBACH-16042-Headlight-LED-Lighting-For-162451-Eschenbach-Max-Detail', 'https://www.ebay.com/itm/272322954859?hash=item3f67b6866b:g:nOQAAOSwZVlXmh5a&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mQ%2Bs8i34CImEO4ghRwxlRZQMgQ4QG5FZQb5BfeOR49x8ZbPJB03KL%2F0s4%2FURX%2BEOH7mWbKccHb2BJ6ry2H6q5iLNNbE5WxA6tdofYQDaw8u4el0JkIpDkZEPDjNv6hptlgJHunFP0i%2Flr%2BXBuBI%2BBPnElUZGBZgdpk9o4qrNc6lUQN5fkzhxg6zoMRkHI2XNXioBo4ZKDHFMBqX7lJ9PiCfK2hqbAeKDnHlM2bCbmb%2F%2BUjWvjXxcAotDxH0IHDJKjDrR5Di%2BtDZHceGh8Uqfm2%7Ctkp%3ABk9SR-aNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/s6cAAOxyuCJRc45c/s-l400.jpg', '$34.91']
# [34, '$197.31', 'ST.DUPONT TITANIUM LUNETTE EYEGLASSES SUNGLASSES GLASSES FRAME OCCHIALI', 'https://www.ebay.com/p/642365951?iid=391478136689', 'https://i.ebayimg.com/thumbs/images/g/jxoAAMXQHO9RfljU/s-l400.jpg', '$52.54']
# [35, '$68.60', 'Jimmy Choo glasses, glasses frames, y2k, glamour, alternative, diamonds', 'https://www.ebay.com/itm/395892510018?hash=item5c2d084d42:g:TK4AAOSw0FBnMmqO&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30kwQj9d%2BWK%2BxRfMRV1yHMFxsY7Rb1f9NTCGOBsjuNp3MGKNwTfh9i5mXlvA2A5FKWGc2Prrb%2FDqd5cqLj%2B%2FfAawXg6hyJdd%2FUiff7iTupkp6kn0JuUlnVWrCjcU1H3SG6MDUVukczn8NFXsIFo8VkrvxzWrnU3HfiWV22mBmKX7CvyaT8JR235WjSsQQ3T3OJevLLvp024raEVmLj3YqMXq5wIAOBw3m4qrCl0q4l7hBktscNIMgrISm%2FXSL54ZUS8bW7XQ1U%2BWCyCgDVJ7uwFX%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/-VcAAOSwI-BWL4fn/s-l400.jpg', '$8.23']
# [36, '$185.63', 'ST.DUPONT BEZEL GLASSES LENS FRAME HALF FRAME GLASSES EYEGLASSES EYEGLASSES EYEGLASSES', 'https://www.ebay.com/itm/325748458153?hash=item4bd81f02a9:g:O6YAAOSwqu9U-cZ4&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30n8kXrnfEfGZtF2VnCTzGJEF62G0XfOmnLzKPKMC3jwNoeDsg6YOPGzPOCsWjAXZSaiknuz37vshM%2BLgEIk2VjNUF8x8CPLgfsvhuDcJrXu6ETD2zdiGJ0iOcnvsvPenhgLeUjlOcYM93xjXMCTFwBoJoFT9jY8Pg5J3P7MaN9BxZ90ujg04OsTM7ozR0L1MOnauN7QQqk1lVAk6InxE%2FTQRe5CjJ7UE6%2BKSEYtlCwJ3g%3D%3D%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/yOsAAOxyuCJRfgRp/s-l400.jpg', '$52.54']
# [37, '$185.63', 'ST.DUPONT TITANIUM GLASSES EYEGLASSES FRAME GLASSES RARE', 'https://www.ebay.com/itm/391493180333?hash=item5b26cfdbad:g:iXcAAOxyUgZSLyfR&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nfh5Er8hLparEp6mI5%2FOmW8ksJKjLkX2%2BKX4lFnvuXeL3T9W7un%2BSioBaYlm5aG7tc20XSBN2cygWIIEcz9p8w%2FTkrXny5HCh9wzugsSdLVIzFqFT43GtvbWj%2BDCQ5WpZdrwZFqaTF6atPWWO%2BZre2ee1Z8BXspiPm9VcmqaqThlBBFJnJmLAqi3rDb5X2k7UoueYlAiOSJ4H4DM%2F59%2BE4jVUVIwM3326Yw%2BtaMhdkcCBv5EuA03zMQTX6unswKxhvEv08JgiQ4Gqd47JnQQRv%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/UAIAAMXQn11RfOT3/s-l400.jpg', '$52.54']
# [38, '$116.75', 'Prada Eyeglasses Women New (R -1.25L -0.75)', 'https://www.ebay.com/itm/174425694724?hash=item289c94e204:g:dq8AAOSwAx1fVdSy&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30k6C%2FoZUy%2FdLWKFdOdCnrW2p7pvAWjwsB583rs1EW45ZcHkWfFimg8uX%2FyiLm4LapF2r%2BShn8jBxgQU4jFzEMHvQCjOhHNj%2Bk8DKnrWydLw%2F3fe3JBCsKnanbGeYgmIisbNWp8cQgKBzEPn8BUZl2%2BvxgIuvAJNLUcSiWFlvY%2FayRQbBRszJ7mKpGpJMNoWedIrSMRT6pFIiQeoI8u35rM%2BaIdg7E6t8kME4ffVlvdxdMoKcAVRKzRltCUsgOceDEShiEzuw%2Fh%2BHxRwnmWINAv%2B%7Ctkp%3ABFBM6I3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/qG8AAMXQslhRka56/s-l400.jpg', '$13.30']
# [39, '$185.63', 'S.T.DUPONT LUNETTE D-LIGNE EYEGLASSES FRAMES EYE-GLASSES FRAME OCCHIALI ОЧКИ', 'https://www.ebay.com/itm/391492110148?hash=item5b26bf8744:g:Gx8AAOSw9mFWMMwK&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30k3SV9mI9CAJSPHwnGAOOcXVRA28TlfqAfWVVXOPt3Aaj3dI7CXHgW7fdGU6Jt4ZUkdp4TElm7T1l30pP73p2IpoO1Po%2BaRrtbX0pI58ZFmb5sLomWCfqC%2B8xUFC6chEJD7CvnTB2mJvbUnP3f9eyvjVMUo9Qse0LcnkgyAW3GBq%2Bz5LNRa1jMGkrw%2BR%2Fz4levEICkGI5fMznLK8qEvc3prIwF8y1wAPGmelAREPG4z3OkqfTWurG4L2r4ETDxZUG%2Bjxmkfe04weNTdY0ZELxOi%7Ctkp%3ABFBM6I3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/oOYAAOxy79VRc8nn/s-l400.jpg', '$52.54']
# [40, '$185.63', 'ST.DUPONT GLASSES GLASSES PVD-FINISH HALFFRAME EYEGLASSES GLASSES BEZEL', 'https://www.ebay.com/p/637497344?iid=322168170147', 'https://i.ebayimg.com/thumbs/images/g/Am4AAOSwJn1mHOY8/s-l400.jpg', '$52.54']
# [41, '$185.63', 'ST.DUPONT LUNETTES EYEGLASSES FRAMES GOLD & ACETATE EYEGLASSES FRAME OCCHIALI', 'https://www.ebay.com/p/637082072?iid=394780045948', 'https://i.ebayimg.com/thumbs/images/g/Am4AAOSwJn1mHOY8/s-l400.jpg', '$52.54']
# [42, '$208.98', 'ST.DUPONT TITANIUM LUNETTES EYEGLASSES FRAMES EYE GLASSES FRAME OCCHIALI NEW', 'https://www.ebay.com/itm/322167596731?hash=item4b02af66bb:g:JkUAAOSwT5tWMNcK&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30l%2Fbp6LPxNZL2n2gw6wFYsFfwz6gF--qY8cp%2F12T5cgakTixHJHHj5mARP0FzgKEVHInHvDWd4rJRFUGRFdOTAaD3RPZEBH7Nu4KJ6KMhczuFRxl9oMz2cFCaZ1j%2F2J8RGXYAH5ZkhjUOgyypjVsNf4QYWzxvLBSDEKso5CDypUsdhCUsMZX2Y2DEb%2FZFM3DOtKi1gQcq9y4sQ%2BTj7Q52BDTSuxKCU7B%2Bi4uDCO3oFLVA%3D%3D%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/1HkAAMXQJ3xRfqbV/s-l400.jpg', '$52.54']
# [43, '$210.15', 'New Eyeglasses Semi Rimless Progressive Prescription Glasses Lens Trivex 1.53, Supe', 'https://www.ebay.com/itm/113715542099?hash=item1a79f97853:g:r04AAOSwaEhZNG4M&itmprp=enc%%2F38uX%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/ojAAAMXQwKdRbrSm/s-l400.jpg', '$9.22']
# [44, '$173.96', 'ST.DUPONT GLASSES EYEGLASSES FRAME GLASSES EYEGLASSES GLASSES VINTAGE BEZEL RARE', 'https://www.ebay.com/itm/394785988419?hash=item5beb141f43:g:Vg0AAMXQJ3xRfS1F&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lEVaXDAekhDIaYCFYzhgsYfqJeLESZktcxKJgXaPt4PqVDVs7hSAE1RCiQ7u61XEp%2BHUjKpr%2FlPV2L5BRQMAtT2U4bPkGNsXLcYf0lwY6t2YXYGYJgx8rEhAlF8ZONPgdnwB%2FKAE3FokrzYreScaKDyflL0ocdP%2BsUgwmuPt3f%2FLS56Qyaic%2BYSyqjudOkRCof2DuxObIpWjGeQj2T73ZJn2ho1hagf7SkPDsxX0Ze2%2BEWrXXWfSbi%2BQFpTslA8OcMeI2EbOyUqKjRiG6Xr1ZU%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/J8cAAOSwMpZUotMk/s-l400.jpg', '$52.54']
# [45, '$173.96', 'ST. DUPONT LUNETTES EYEGLASSES GLASSES FRAMES EYEGLASSES FRAME OCCHIALI RARE', 'https://www.ebay.com/p/640873708?iid=325754922162', 'https://i.ebayimg.com/thumbs/images/g/nOQAAOSwZVlXmh5a/s-l400.jpg', '$52.54']
# [46, '$173.96', 'ST.DUPONT TITANIUM BEUNETTE EYEGLASSES FRAMES EYE GLASSES FRAME OCCHIALI RARE', 'https://www.ebay.com/itm/392614760463?hash=item5b69a9d00f:g:b1cAAOxy79VRfL~R&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lvu3ZpLrn04xVOFTrnB2EUcUSBaB9wka67IKexZ%2BA7YKE4YjdGNdVYXrjqDAuD5txqpPeZnI1cCm89%2BsgNyfbgy0ST37s%2FV%2Bvc3AFcGrPKtF1NDkxgdYkFEIuymTHLJFG3tSH0jGRDEKBT4NVgChv3Ga2QgqURZUNXE2l1UAUBVxcJOgjd7Tg2%2BedmdqA1TS%2Bf%2B%2FafHSgWIe4CwO2l2biufixcyweb4ffgV8ewa3Ylv30JaIL8w8TMW%2BOzcYwKpu3XzbOQU0mOBVVS%2FTCEQ7sO%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/650AAMXQQQhRfmbz/s-l400.jpg', '$52.54']
# [47, '$185.63', 'ST.DUPONT GLASSES GLASSES EYEGLASSES FRAME GLASSES ОЧКИ VINTAGE', 'https://www.ebay.com/itm/391492117949?hash=item5b26bfa5bd:g:128AAOSw93xdmvFu&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lRWqpef9r8HGLpu6EKHKCQcC75V7r5mmTdzxfP43iPD6bVxXW1l17KpxVyqPGQoeuX4i2cFpla11IkWSpNNppRAGBAHDtOVwXrYsCYCMgmwN%2FHxLwoBGA0kbL2wRYiexjiAsGXNZUGmmgFeoUCsSrdRsLnWSiDoWxnUcEcDV%2FAfQQEY1OnevF6CoZ%2FurPujwYcfGVCJ63u3ZvYd7IW8bqY3N9veuxyfD64vN2bdfmftsFitjOhpnuVr2I3t1%2BBxO9p7r%2Bh5wGq6vdnS9%2BIsA4o%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/TK4AAOSw0FBnMmqO/s-l400.jpg', '$52.54']
# [48, '$173.96', 'ST.DUPONT TITANIUM LUNETTES EYEGLASSES FRAMES EYE GLASSES FRAME OCCHIALI RARE', 'https://www.ebay.com/itm/325747328349?hash=item4bd80dc55d:g:En0AAMXQsmFRc81G&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30mpE9uUfvxQV2eXxrOeRKHy33Jxqg%2B27jzkyQZUXNwRaFppLGDzIElFCRBe3NpNQj1fm2GTcOQXKFSQQ71sapQqF6DVqTkks34N9AiTMLT2oSvM7hrZmiLde9n7BcLwxGQ7GF3Lv%2FvgoOphkcAJP2VjqGVeZycprMK%2F6DmViBJ5PcVCZrBUmP6kxTXuYBcLoD%2BoNUyHcEZ4qbCJMT4nm7Gy%2FvdBGOC0ei9fJQhyuFM4Hg%3D%3D%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/O6YAAOSwqu9U-cZ4/s-l400.jpg', '$52.54']
# [49, '$197.31', 'ST.DUPONT BEZEL GLASSES FRAME HALF-GRAM EYEGLASSES SUNGLASSES GLASSES GLASSES', 'https://www.ebay.com/itm/392256335320?hash=item5b544cadd8:g:cGUAAOSwpDdU-cZz&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30k9gd9q4H1%2B6nw%2FlVtz9KryLmPqX779ww0KXN5RBL8lfH92EfFylsPr1ZkOYB3jmHKNZqiyXcE2ixMLz4hs3PlHiBot0Ptf6odw3jblGxgspZiaOK3AvYCY3VlnEYiyFJcBgXp4Qj32nbchwG23Lv%2BLA2nRrw4bOAWH1%2Btxg5H8D6itL%2FX3cFdfVF%2FIGEKvMjpryd1Td95KQWYcjng3kpSeBmgBSLObzun6%2FXwEz5TzRg%3D%3D%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/iXcAAOxyUgZSLyfR/s-l400.jpg', '$52.54']
# [50, '$40.88', 'Valentino prescription glasses frames', 'https://www.ebay.com/itm/145744946977?hash=item21ef136721:g:gIsAAOSw8yJmKzFJ&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30m0XH6PTMXND3EgtUQnnjdwCNfOY601y9tGE2j51kyAUO%2BPrCKJ0ZWVcRyZF6rrH5kL838BTFropbqkFhbb0z2Vwk6qcmQ%2FWbE38X0FK1JjoQRW6nLzavMhEBH5ihD7qoxoLFvhL%2BI0ARaS%2Bs4NwTBttcebZ6oleEba812pNnva9%2FFbQwNh0G%2FWN1oWOIJW6r0Ddo0ktLpRBAWCA6R%2FSwGH9HX%2B%2Flv8d3f5K1lD6HsueMPwFh2YYMrmGpWQIXdtbIAhAhwF%2BbjOtVA9wre2FHK%2B%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/dq8AAOSwAx1fVdSy/s-l400.jpg', '$7.13']
# [51, '$244.01', 'ST.DUPONT TITANIUM LUNETTE EYEGLASSES SUNGLASSES GLASSES FRAME OCCHIALI', 'https://www.ebay.com/itm/325285369484?hash=item4bbc84d68c:g:SvcAAOSw8d9Uv8Dy&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nCPne55WlSJ21sUnvJ3wMIuE7M7BWzmi58JETSH6Fwxtvz%2FS40QcPhwzGy25WeZfKAbfZlbuQVLnTpuRouEgTdkPOwNIVWYm%2FzY90hiIT%2BeHXgtgZMh4EX3166gynvto42soAPVMm3czUup1dUIXIpfxWl%2Bf3uiQXKS7Tr1TqyImhf3ZgNNEoyuidQyLY%2BfBKUmMt2VvaQOYRzs8kvFeG8yLPMwNFfwfPuFtwNudOy0nSwDDKljETHjKQCibbr2Q7KywUuiPRI6IMohvmgtYql%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/Gx8AAOSw9mFWMMwK/s-l400.jpg', '$52.54']
# [52, '$80.67', 'Alexander McQueen prescription glasses frames', 'https://www.ebay.com/itm/145727793877?hash=item21ee0daad5:g:9SwAAOSwa0FmHg3D&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30kLq3pkk1Sl8RoxQJ%2FgkbzmxaY5qK6trn5wCvDXaV%2BzYF%2F5zfeZCmLha0a5B5NNvMdQHzxXVQdASHXtd775rc4o5DlpxfgDXYX%2FPRPEGHvUX4FHY%2Fcxs71e8NNCUSpbVA3ukme4pYu%2FCSkbuffL2gvPyPeWBS89GXBuE225X7VHNKcI9f23Au1sd56EH5EAXse2VgMMmoxpPmN6%2BxYlKyiOlvj0pplCIFkq7RkL8KjPtg%3D%3D%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/V~QAAMXQn11Rc6KG/s-l400.jpg', '$7.13']
# [53, '$185.63', 'S.T.DUPONT LUNETTES EYEGLASSES GLASSES EYEGLASSES FRAME OCCHIALI RARE', 'https://www.ebay.com/itm/394780019921?hash=item5beab90cd1:g:I9QAAMXQJ3xRc8Q2&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mz3LTQawSTOqaJtl95MER0gLVhsh3b6sACS3hONT%2FGmU0Ekj8VZ4sfF2rJ4HVM%2BB45g3fXpKzMZEFtu9eMt2c9Fbx3LX0KyGPzDkxwEdLIyYQMUr3QkTbRLME3nLlf%2BmSWMlnxinNLQZZ4b%2BUAUvcP0CgS1CdLzX5rYH0vyQpmDB4DQgrrwcZ%2FUK%2FvjJNOKdyBStlC03Iv1ZXnlkXfIK1t47GY1uDxeassf%2FPUgcZVMiMtB1Fkwhlh78OT4YxlqlG0yAFGmhDcvBs2xNlHv3Cu%7Ctkp%3ABk9SR-iNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/zo8AAMXQHDlRcs~3/s-l400.jpg', '$52.54']
# [54, '$173.96', 'ST.DUPONT GLASSES EYEGLASSES FRAME GLASSES RARE', 'https://www.ebay.com/itm/391487237839?hash=item5b26752ecf:g:3jAAAOxyQj9RN49F&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mHLgLUhN2ilWJpfXUo6CGXqvNCzytf00knEyIp76loaH02qpv3bMLl5uG97PBSFg2gpou4zGlcJ3PFZHq%2B8seZEDttIgGa3%2BOQ6Z1FXczEzqjanUWHsZbOw79YHm0QZLcpi4sDpFY71wfEtXWTb42gOpr5CYxXJCQnaSJOtHnsrzUC2jfbJuD14%2Fj%2FnUTz614QTpRQQZOwu%2F7OAmF8Uqc0kERoC3GoSJtnTR0NMaTQQrH3GSy97ryPOsFNIPY%2FnsefznF0troMzG8U88%2B0Re9l%7Ctkp%3ABk9SR-qNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/JkUAAOSwT5tWMNcK/s-l400.jpg', '$52.54']
# [55, '$173.96', 'S.T. DUPONT GLASSES EYEGLASS SOCKET SUNGLASSES FRAME GLASSES', 'https://www.ebay.com/p/643734158?iid=394785911340', 'https://i.ebayimg.com/thumbs/images/g/r04AAOSwaEhZNG4M/s-l400.jpg', '$52.54']
# [56, '$452.74', 'Okulary korekcyjne', 'https://www.ebay.com/itm/395112573077?hash=item5bfe8b6895:g:ewsAAOSwVWJll1TN&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lchWjs8ieClz4f7zIALUEAl8ZqbOaY3LMe%2B5KFE86qcPQKCjUPRz4UqhbK9wnP5qJGGRnJmkV6sHV0dxDlugGQ%2Fvz%2BWjA9Pf4GIAwFk%2B9slZARSH1lF8XBkhDn9khoPPeZqCMIM9KHFYLVXUrZBnMIE%2FJ8xm4Qau5Tw2r0kfuxVJ4YdUs9L%2F2m6eG65WZkbIXy9K4Qqi783hJr3s4oWLQmI89THfGZpIPR92pjl23W4wEg8ejE1xbWvXcFCEl0%2BZOmr9jB5k65FodtyrL6EPPL%7Ctkp%3ABk9SR-qNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/Vg0AAMXQJ3xRfS1F/s-l400.jpg', '$41.16']
# [57, '$15.17', 'INTER 2186 PA (orFA) glasses, burgundy, no reading glasses', 'https://www.ebay.com/itm/305270572015?hash=item47138b43ef:g:zpcAAOSwRe9lVPvK&itmprp=enc%3AAQAKAAAAwMHg7L1Zz0LA5DYYmRTS30k32Vu5Lozky4Gu6AGdK6N3uod3rbuY62%2BIDihcQ%2FmTqlHZ6rxYTpujH6JmK3Z7cG%2BteiHbBThI20%2BZcrzDs6g5aHjM45bNhggoO28Vd1JIrdZ%2Fuvwg%2Bfm357rS3Gaj4EfCppdtsrE7Bn7IcloXmv4rJfxfGrwc1URR3rKZdRgVmB91wBE95WdL%2FszW0FM%2BNvzr5wFOH2lTa5A%2FC7mC8Mi8ry2XBXo87Jp9EcKW%2FqizZg%3D%3D%7Ctkp%3ABk9SR-qNx8GUZg', 'https://i.ebayimg.com/thumbs/images/g/~aEAAOxybi9Rc5II/s-l400.jpg', '$17.40']
# [58, '$173.96', 'ST.DUPONT TITANIUM BEZEL GLASSES EYEGLASS FRAME GLASSES RARE', 'https://www.ebay.com/itm/325755398325?hash=item4bd888e8b5:g:k1AAAOSwuzRXdEVq&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30kFeVq95Wp1Z6QvXhJwCeR9ht99I78tnrhVf8BbJbJ%2F6eojTpXiravEquY%2FRy9TDqxrafJdT4C7mE7tjAigGPjAXrZofxom13LvBr2ANA6WTCaLEizh%2BET%2BrTEHkohOLA1B6PLnOzSjvdkuvcE%2B5LfkJFXLb09QXQG%2FML%2BvdWC0nqG%2BdG1j271RGo2sIkcsg4S8YwtvWKRBuKItVvBzDY22RW1XmyKClE34K1jDE%2FH4o10WZMigEMRacF0J9YbCWnOjgpRZHqnSXI6%2F9EN1JzJE%7Ctkp%3ABFBM6o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/b1cAAOxy79VRfL~R/s-l400.jpg', '$52.54']
# [59, '$87.56', 'X5 Love Moschino Hilfiger Kate Spade Glasses Worldwide Post For Free', 'https://www.ebay.com/itm/256684547415?hash=item3bc3975d57:g:Ul0AAOSw6~9nFlJC&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nvWFLDL95A8pTQUI7y1OWUigjvgjscH1sqTs4ghshOlkKbjMkRE3BwzZz4naAt8UIhot98Bji9wNza3HLhdYrOmBPVaUsn2mNJF5X2JpALF1Odz31OY1EQ3XISDJIaTppnpzG6gJOuHe301CBZWQmu4KzlajJAFqmQ%2Bj54PBZWjocpqqYkVusEYjFSTNOPA0TZmKEVK0MZ4YzL7FLwiQN4lnYzePEUEtokik589IbfeXLSsT%2FsiOoad6nvZ9FJ2iSkYr5%2FNfAp9IUol56hPkfx%7Ctkp%3ABFBM6o3HwZRm', 'https://i.ebayimg.com/thumbs/images/g/128AAOSw93xdmvFu/s-l400.jpg', '$3.50']

# %%
import time
def get_condition():
    global condition
    condition = {}
    for i in range(len(list_of_items)):
        URL2 = list_of_items[i][3]
        headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/125.0.0.0 Safari/537.36"
    ),
    "Accept": (
        "text/html,application/xhtml+xml,application/xml;q=0.9,"
        "image/avif,image/webp,image/apng,*/*;q=0.8"
    ),
    "Accept-Language": "en-US,en;q=0.9,ar;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Cache-Control": "no-cache",
    "Pragma": "no-cache",
    "Sec-Ch-Ua": '"Not/A)Brand";v="8", "Chromium";v="125", "Google Chrome";v="125"',
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": '"Windows"',
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
    "Sec-Fetch-Site": "none",
    "Sec-Fetch-User": "?1",
    "Upgrade-Insecure-Requests": "1",
}
        r2 = requests.get(URL2, headers=headers)
        soup2 = BeautifulSoup(r2.content, 'html.parser')
        condition_section = soup2.find('span', string='Condition:')
        if condition_section:
            next_element = condition_section.find_next('span', class_='ux-textspans')
            if next_element:
                condition_found = next_element.get_text(strip=True)
        text = condition_found
        if text in condition:
            condition[text] += 1
        else:
            condition[text] = 1
        print(condition)

get_condition()
# Out:
# {'New with tags': 1}
# {'New with tags': 1, 'Used': 1}
# {'New with tags': 1, 'Used': 1, 'New without tags': 1}
# {'New with tags': 1, 'Used': 1, 'New without tags': 2}
# {'New with tags': 1, 'Used': 1, 'New without tags': 3}
# {'New with tags': 1, 'Used': 1, 'New without tags': 3, 'Pre-owned': 1}
# {'New with tags': 1, 'Used': 1, 'New without tags': 4, 'Pre-owned': 1}
# {'New with tags': 1, 'Used': 1, 'New without tags': 4, 'Pre-owned': 1, 'New': 1}
# {'New with tags': 1, 'Used': 1, 'New without tags': 5, 'Pre-owned': 1, 'New': 1}
# {'New with tags': 1, 'Used': 1, 'New without tags': 5, 'Pre-owned': 1, 'New': 2}
# {'New with tags': 1, 'Used': 1, 'New without tags': 5, 'Pre-owned': 1, 'New': 3}
# {'New with tags': 1, 'Used': 1, 'New without tags': 5, 'Pre-owned': 1, 'New': 4}
# {'New with tags': 2, 'Used': 1, 'New without tags': 5, 'Pre-owned': 1, 'New': 4}
# {'New with tags': 2, 'Used': 1, 'New without tags': 6, 'Pre-owned': 1, 'New': 4}
# {'New with tags': 2, 'Used': 1, 'New without tags': 6, 'Pre-owned': 1, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 7, 'Pre-owned': 1, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 7, 'Pre-owned': 2, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 7, 'Pre-owned': 3, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 8, 'Pre-owned': 3, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 9, 'Pre-owned': 3, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 10, 'Pre-owned': 3, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 11, 'Pre-owned': 3, 'New': 5}
# {'New with tags': 2, 'Used': 1, 'New without tags': 11, 'Pre-owned': 3, 'New': 6}
# {'New with tags': 2, 'Used': 1, 'New without tags': 12, 'Pre-owned': 3, 'New': 6}
# {'New with tags': 2, 'Used': 1, 'New without tags': 13, 'Pre-owned': 3, 'New': 6}
# {'New with tags': 2, 'Used': 1, 'New without tags': 14, 'Pre-owned': 3, 'New': 6}
# {'New with tags': 2, 'Used': 1, 'New without tags': 15, 'Pre-owned': 3, 'New': 6}
# {'New with tags': 2, 'Used': 1, 'New without tags': 15, 'Pre-owned': 3, 'New': 7}
# {'New with tags': 2, 'Used': 2, 'New without tags': 15, 'Pre-owned': 3, 'New': 7}
# {'New with tags': 2, 'Used': 3, 'New without tags': 15, 'Pre-owned': 3, 'New': 7}
# {'New with tags': 2, 'Used': 3, 'New without tags': 15, 'Pre-owned': 3, 'New': 8}
# {'New with tags': 2, 'Used': 3, 'New without tags': 16, 'Pre-owned': 3, 'New': 8}
# {'New with tags': 2, 'Used': 3, 'New without tags': 17, 'Pre-owned': 3, 'New': 8}
# {'New with tags': 3, 'Used': 3, 'New without tags': 17, 'Pre-owned': 3, 'New': 8}
# {'New with tags': 3, 'Used': 3, 'New without tags': 17, 'Pre-owned': 3, 'New': 9}
# {'New with tags': 3, 'Used': 3, 'New without tags': 17, 'Pre-owned': 3, 'New': 10}
# {'New with tags': 3, 'Used': 3, 'New without tags': 17, 'Pre-owned': 3, 'New': 11}
# {'New with tags': 3, 'Used': 3, 'New without tags': 18, 'Pre-owned': 3, 'New': 11}
# {'New with tags': 3, 'Used': 3, 'New without tags': 18, 'Pre-owned': 3, 'New': 12}
# {'New with tags': 3, 'Used': 3, 'New without tags': 19, 'Pre-owned': 3, 'New': 12}
# {'New with tags': 3, 'Used': 3, 'New without tags': 20, 'Pre-owned': 3, 'New': 12}
# {'New with tags': 3, 'Used': 3, 'New without tags': 21, 'Pre-owned': 3, 'New': 12}
# {'New with tags': 3, 'Used': 3, 'New without tags': 22, 'Pre-owned': 3, 'New': 12}
# {'New with tags': 3, 'Used': 3, 'New without tags': 22, 'Pre-owned': 3, 'New': 13}
# {'New with tags': 3, 'Used': 3, 'New without tags': 22, 'Pre-owned': 3, 'New': 14}
# {'New with tags': 3, 'Used': 3, 'New without tags': 23, 'Pre-owned': 3, 'New': 14}
# {'New with tags': 3, 'Used': 3, 'New without tags': 23, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 3, 'New without tags': 24, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 3, 'New without tags': 25, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 3, 'New without tags': 26, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 4, 'New without tags': 26, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 4, 'New without tags': 27, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 5, 'New without tags': 27, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 3, 'Used': 5, 'New without tags': 28, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 4, 'Used': 5, 'New without tags': 28, 'Pre-owned': 3, 'New': 15}
# {'New with tags': 4, 'Used': 5, 'New without tags': 28, 'Pre-owned': 3, 'New': 16}
# {'New with tags': 4, 'Used': 5, 'New without tags': 28, 'Pre-owned': 3, 'New': 17}
# {'New with tags': 4, 'Used': 6, 'New without tags': 28, 'Pre-owned': 3, 'New': 17}
# {'New with tags': 4, 'Used': 6, 'New without tags': 28, 'Pre-owned': 3, 'New': 18}
# {'New with tags': 4, 'Used': 6, 'New without tags': 28, 'Pre-owned': 3, 'New': 19}

# %%
def get_sellers():
    global Sellers
    old_Sellers = {}
    Sellers = {}
    for i in range(len(list_of_items)):
        URL2 = list_of_items[i][3]
        headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        }  
        r2 = requests.get(URL2, headers=headers)
        soup2 = BeautifulSoup(r2.content, 'html.parser')
        text1 = soup2.find_all('span', class_="ux-textspans ux-textspans--BOLD")
        print(text1)
        if text1.get_text(strip=True) in old_Sellers:
            old_Sellers[text1.get_text(strip=True)] += 1
        else:
            old_Sellers[text1.get_text(strip=True)] = 1
    
    for i in range(len(old_Sellers)):
        if old_Sellers[list(old_Sellers.keys())[i]] != 1:
            Sellers[list(old_Sellers.keys())[i]] = old_Sellers[list(old_Sellers.keys())[i]]
        else:
            if 'Others' in Sellers:
                Sellers['Others'] += 1
            else:
                Sellers['Others'] = 1
        print(Sellers)


get_sellers()
# Out:
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 31
#      27                 Sellers['Others'] = 1
#      28         print(Sellers)
# ---> 31 get_sellers()
#
# Cell In[29], line 15, in get_sellers()
#      13 text1 = soup2.find_all('span', class_="ux-textspans ux-textspans--BOLD")
#      14 print(text1)
# ---> 15 if text1.get_text(strip=True) in old_Sellers:
#      16     old_Sellers[text1.get_text(strip=True)] += 1
#      17 else:
#
# File c:\Users\omara\anaconda3\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
def get_Country():
    global Hcountries
    Hcountries = []
    for i in range(len(list_of_items)):
        URL2 = list_of_items[i][3]
        headers = {"User-Agent": "Mozilla/5.0"}
        r2 = requests.get(URL2, headers=headers)
        soup2 = BeautifulSoup(r2.content, 'html.parser')
        text1 = soup2.find_all('span', class_="ux-textspans ux-textspans--SECONDARY")    
        for j in range(len(text1)):
            if 'Located in:' in text1[j].get_text(strip=True):
                text2 = text1[j].get_text(strip=True).replace('Located in:', '').replace(' ', '').split(",")
                Hcountries.append(text2[-1])
                print(text2[-1])

    print(Hcountries)
    dict1 = {}
    for i in range(len(Hcountries)):
        if Hcountries[i] in dict1:
            dict1[Hcountries[i]] += 1
        else:
            dict1[Hcountries[i]] = 1
    print(dict1)
    
get_Country()
# Out:
# Germany
# Germany
# Germany
# Germany
# Poland
# Germany
# Germany
# Poland
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Hungary
# Germany
# Germany
# Austria
# Poland
# Poland
# Germany
# Poland
# Germany
# Germany
# Poland
# Germany
# Poland
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Hungary
# Hungary
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Hungary
# Hungary
# Hungary
# Germany
# Serbia
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# Germany
# ['Germany', 'Germany', 'Germany', 'Germany', 'Poland', 'Germany', 'Germany', 'Poland', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Hungary', 'Germany', 'Germany', 'Austria', 'Poland', 'Poland', 'Germany', 'Poland', 'Germany', 'Germany', 'Poland', 'Germany', 'Poland', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Hungary', 'Hungary', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Hungary', 'Hungary', 'Hungary', 'Germany', 'Serbia', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany']
# {'Germany': 39, 'Poland': 7, 'Hungary': 6, 'Austria': 1, 'Serbia': 1}

# %% [markdown]
# PandaCV

# %%
import pandas as pd

if web_type == 'ebay':
    product_data = []
    
    for i in range(len(price)):
        product_info = {
            'Index': i,
            'Price': price[i].get_text(strip=True),
            'Title': titles[i].get_text(strip=True),
            'Link': links[i]
        }
        product_data.append(product_info)
    df = pd.DataFrame(product_data)
    display(df)
# Out:
#     Index            Price                                              Title  \
# 0       0           $29.99  Pokémon Card Team Rocket's Glory sv10 Booster ...
# 1       1           $67.65  USA Authentic popmart Monsters Labubu exciting...
# 2       2           $60.11  X UX-00 Aero Pegasus 3-70A Double Metal Coat T...
# 3       3           $62.94  Endless Spells Hedonites of Slaanesh Chaos War...
# 4       4           $62.94  Action Racing William Byron 2023 #24 RAPTOR 1:...
# ..    ...              ...                                                ...
# 70     70           $24.98              Energizer Ultimate Lithium AA 18-Pack
# 71     71           $53.95  Pokemon TCG: Gemstone Gem Pack “Horizons” Boos...
# 72     72   $2.99to$199.99  2025 McDONALD'S Minecraft Adult Happy Meal TOY...
# 73     73  $60.48to$476.33  Team Rocket’s Glory Attache Case Pokemon Card ...
# 74     74           $54.49  55Pcs Pokemon Card Foil GOLD PACK CARDS TCG GX...
#
#                                                  Link
# 0   https://www.ebay.com/p/21076843292?iid=3166729...
# 1   https://www.ebay.com/p/28067418437?iid=3567185...
# 2   https://www.ebay.com/p/28070315344?iid=3357852...
# 3   https://www.ebay.com/p/16031646113?iid=1768856...
# 4   https://www.ebay.com/p/28060940810?iid=2052299...
# ..                                                ...
# 70  https://www.ebay.com/itm/156835134534?hash=ite...
# 71  https://www.ebay.com/itm/187183472978?hash=ite...
# 72  https://www.ebay.com/itm/116542704733?hash=ite...
# 73  https://www.ebay.com/itm/226707122474?hash=ite...
# 74  https://www.ebay.com/itm/286469906997?hash=ite...
#
# [75 rows x 4 columns]

# %% [markdown]
# Selenium (Rate Search)

# %%
item_choice = int(input("choose the item you want to get it's rating: "))
rating_option = int(input("choose which rating you want (1.item rating, 2. seller rating): "))
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


options = webdriver.ChromeOptions()
options.add_argument("--headless")

def item_rating(x):
      global five_rate_count, four_rate_count, three_rate_count, two_rate_count, one_rate_count
      options = webdriver.ChromeOptions()
      options.add_argument("--headless")

      driver = webdriver.Chrome(options=options)  #Remove 'options=options' to see the selenium open up the window to scrap it
      driver.get(list_of_items[x][3])
      time.sleep(6)
      rating_element = driver.find_element(By.XPATH, '//*[@id="UserReviews"]/div[1]/div[2]/span[1]').text
      count = driver.find_element(By.XPATH, '//*[@id="UserReviews"]/div[1]/div[2]/span[2]').text
      allrate_count = ''.join(i for i in count if i.isdigit())
      five_rate_count = driver.find_element(By.XPATH, '//*[@id="s0-0-21-5-60-9"]/ul/li[1]/div/div[2]/span').text
      four_rate_count = driver.find_element(By.XPATH, '//*[@id="s0-0-21-5-60-9"]/ul/li[2]/div/div[2]/span').text 
      three_rate_count = driver.find_element(By.XPATH, '//*[@id="s0-0-21-5-60-9"]/ul/li[3]/div/div[2]/span').text 
      two_rate_count = driver.find_element(By.XPATH, '//*[@id="s0-0-21-5-60-9"]/ul/li[3]/div/div[2]/span').text
      one_rate_count = driver.find_element(By.XPATH, '//*[@id="s0-0-21-5-60-9"]/ul/li[5]/div/div[2]/span').text

      print('over all rating:', rating_element , '\n', 
                  'all rating count:' , allrate_count, '\n', 
                  'five star rating:' , five_rate_count, '\n', 
                  'four star rating:' , four_rate_count, '\n' , 
                  'three star rating:' , three_rate_count, '\n' , 
                  'two star rating: ' , two_rate_count, '\n' , 
                  'one star rating:' , one_rate_count)
      
      driver.quit()
      
def seller_rating(x):
      global acc_rate, ship_cost, ship_speed, comm
      options = webdriver.ChromeOptions()
      options.add_argument("--headless")
      driver = webdriver.Chrome(options=options)
      driver.get(links[x]) 
      time.sleep(6)
      acc_rate = driver.find_element(By.XPATH, '//*[@id="STORE_INFORMATION"]/div/div/div[1]/div[2]/div/div/div[2]/div[1]/span').text
      ship_cost = driver.find_element(By.XPATH, '//*[@id="STORE_INFORMATION"]/div/div/div[1]/div[2]/div/div/div[2]/div[2]/span').text
      ship_speed = driver.find_element(By.XPATH, '//*[@id="STORE_INFORMATION"]/div/div/div[1]/div[2]/div/div/div[2]/div[3]/span').text
      comm = driver.find_element(By.XPATH, '//*[@id="STORE_INFORMATION"]/div/div/div[1]/div[2]/div/div/div[2]/div[4]/span').text
            
      print('Accurate description rating: ', acc_rate , '\n',
                  'Shipping cost rating:' , ship_cost, '\n', 
                  'Shipping speed rating:' , ship_speed, '\n', 
                  'Customer service rating:' , comm)
      
      driver.quit()
      
if rating_option == 1:
      try:
            item_rating(item_choice)
            review = True            
      except:
            print('this item has no review written, you can check the link: ' , links[item_choice])
            review = False
elif rating_option == 2:
      try:
            seller_rating(item_choice)
            review = True 
      except:
            print('this item has no seller rating written, you can check the link: ' , links[item_choice])
            review = False
# Out:
# Accurate description rating:  4.9
#  Shipping cost rating: 4.9
#  Shipping speed rating: 5.0
#  Customer service rating: 5.0

# %%
import matplotlib.pyplot as plt
import os
def show_Item_graph():
    labels = ['5-Star Rate', '4-Star Rate', '3-Star Rate', '2-Star Rate', '1-Star Rate']
    sizes = [five_rate_count, four_rate_count, three_rate_count, two_rate_count, one_rate_count]

    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.title('Item Rating')
    data_path = os.path.join(os.getcwd(), '..', 'data', 'item_Graph.jpg')
    data_path = os.path.abspath(data_path)  # Make sure it's absolute

    if os.path.exists(data_path):
        os.remove(data_path)

    plt.savefig(data_path)
    plt.show()

def Show_seller_graph():
    labels = ['Accurate description rating', 'Shipping cost rating', 'Shipping speed rating', 'Customer service rating']
    sizes = [acc_rate, ship_cost, ship_speed, comm]

    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.title('Item Rating')
    data_path = os.path.join(os.getcwd(), '..', 'data', 'Seller_Graph.jpg')
    data_path = os.path.abspath(data_path)  # Make sure it's absolute

    if os.path.exists(data_path):
        os.remove(data_path)

    plt.savefig(data_path)
    plt.show()

# %% [markdown]
# NetworkX

# %%
# Networkx
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os

def is_number(x):
    try:
        float(x)
        return True
    except:
        return False

low_num = int(input('Enter the starting number: '))
high_num = int(input('Enter the ending number: '))
diff_limit = int(input('Enter difference limit number: '))

def networkx_graph(low_num, high_num, diff_limit):
    all_prices = []
    for item in list_of_items:
        try:
            price_str = item[1].replace('$', '').replace(',', '')
            if is_number(price_str):
                price = float(price_str)
                all_prices.append(price)
            else:
                print('Skipped item', item[0], 'due to pricing issue')
        except Exception as e:
            print(f'Skipped item due to error: {e}')

    G = nx.Graph()
    sub_prices = all_prices[low_num:high_num]
    G.add_nodes_from(sub_prices)

    for i in range(len(sub_prices)):
        for j in range(i + 1, len(sub_prices)):
            diff = abs(sub_prices[i] - sub_prices[j])
            if diff <= diff_limit:
                G.add_edge(sub_prices[i], sub_prices[j])

    degree = dict(G.degree)
    print('Degree =', degree)
    centrality = nx.betweenness_centrality(G, normalized=False)
    print("Betweenness centrality =", centrality)

    fig, ax = plt.subplots(figsize=(12, 8))
    pos = nx.spring_layout(G, k=0.5, seed=42)

    degrees = list(degree.values())
    node_colors = [cm.plasma(deg / max(degrees) if max(degrees) > 0 else 0) for deg in degrees]
    node_sizes = [200 + deg * 300 for deg in degrees]

    nodes = nx.draw_networkx_nodes(G, pos,
                                   node_size=node_sizes,
                                   node_color=node_colors,
                                   cmap=cm.plasma,
                                   alpha=0.9,
                                   edgecolors='black',
                                   linewidths=1,
                                   ax=ax)

    nx.draw_networkx_edges(G, pos, width=1.5, alpha=0.4, edge_color='gray', ax=ax)

    nx.draw_networkx_labels(G, pos,
                            font_size=10,
                            font_color='white',
                            font_weight='bold',
                            ax=ax)

    sm = plt.cm.ScalarMappable(cmap=cm.plasma, 
                               norm=plt.Normalize(vmin=min(degrees), vmax=max(degrees)))
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, shrink=0.7)
    cbar.set_label('Node Degree')

    ax.set_title('Price Network Graph', fontsize=16, pad=20)
    ax.axis('off')

    data_path = os.path.join(os.getcwd(), '..', 'data', 'NetX_Graph.jpg')
    data_path = os.path.abspath(data_path)  # Make sure it's absolute

    if os.path.exists(data_path):
        os.remove(data_path)

    plt.savefig(data_path, bbox_inches='tight', dpi=300)
    plt.show()

networkx_graph(low_num, high_num, diff_limit)
# Out:
# Skipped item 10 due to pricing issue
# Degree = {150.61: 8, 39.7: 5, 185.63: 8, 577.91: 4, 1745.41: 0, 208.98: 6, 221.71: 6, 58.26: 5}
# Betweenness centrality = {150.61: 0.5, 39.7: 0.0, 185.63: 0.5, 577.91: 0.0, 1745.41: 0.0, 208.98: 0.5, 221.71: 0.5, 58.26: 0.0}
# c:\Users\omara\anaconda3\Lib\site-packages\networkx\drawing\nx_pylab.py:450: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(

# %% [markdown]
# Country Finder | Heatmap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import os
import cv2

def kde_quartic(d, h):
    """
    Quartic kernel function for KDE as described in the lecture
    d: distance
    h: bandwidth (radius)
    """
    if d <= h:
        dn = d/h
        return (15/16) * (1 - dn**2)**2
    else:
        return 0

def HeatOnMap():
    counties2 = Hcountries

    country_counts = pd.Series(counties2).value_counts().reset_index()
    country_counts.columns = ['country', 'count']

    country_coords = {
        'UnitedStates': (20, -90), # 37.0902, -95.7129
        'China': (15, 75), # 35.8617, 104.1954
        'UnitedKingdom': (27, -15), #- 55.3781, -3.4360
        'Japan': (16, 108), # 36.2048, 138.2529
        'Germany': (24, -5), #- 51.1657, 10.4515
        'France': (22, -10), #- 46.2276, 2.2137
        'Italy': (19, 0), #- 41.8719, 12.5674
        'Canada': (30, -110), # 56.1304, -106.3468
        'Australia': (-17, 105), # -25.2744, 133.7751
        'Spain': (19, -14), #- 40.4637, -3.7492
        'Brazil': (-10, -55), # -14.2350, -51.9253
        'India': (5, 55), # 20.5937, 78.9629
        'Mexico': (10, -98), # 23.6345, -102.5528
        'Poland': (26, 5), #-
        'Hungary': (22, 5), #-
        'Austria': (23, 0),
        'HongKong': (8,87),
        'SouthKorea': (17,97),
        'SriLanka': (0,58),
        'Malaysia': (0,75)
    }

    lats = []
    lons = []
    weights = []

    for index, row in country_counts.iterrows():
        country = row['country']
        count = row['count']
    
        if country in country_coords:
            lat, lon = country_coords[country]
            lats.append(lat)
            lons.append(lon)
            weights.append(count)

    resolution = 1.0
    lat_grid = np.arange(-60, 80, resolution)
    lon_grid = np.arange(-180, 180, resolution)
    density_grid = np.zeros((len(lat_grid), len(lon_grid)))

    bandwidth = 15.0

    for i, lat in enumerate(lat_grid):
        for j, lon in enumerate(lon_grid):
            total_density = 0
            for k in range(len(lats)):
                d = np.sqrt((lat - lats[k])**2 + (lon - lons[k])**2)
            
                density = kde_quartic(d, bandwidth) * weights[k]
                total_density += density
        
            density_grid[i, j] = total_density

    hot_colors = ['black', 'darkred', 'red', 'orange', 'yellow', 'white']
    hot_cmap = LinearSegmentedColormap.from_list('hot_custom', hot_colors)

    plt.figure(figsize=(14, 8))

    lon_mesh, lat_mesh = np.meshgrid(lon_grid, lat_grid)

    plt.contourf(lon_mesh, lat_mesh, density_grid, levels=50, 
                 cmap=hot_cmap, alpha=0.7)

    for i in range(len(lats)):
        plt.scatter(lons[i], lats[i], s=weights[i]*20, 
                    color='blue', alpha=0.7, edgecolors='white')
        plt.text(lons[i], lats[i], country_counts.iloc[i, 0], 
                 fontsize=8, ha='center', va='bottom', 
                 bbox=dict(facecolor='white', alpha=0.5))

    cbar = plt.colorbar(orientation='vertical', pad=0.01, shrink=0.8)
    cbar.set_label('Density (based on quartic kernel)')

    plt.grid(True, linestyle='--', alpha=0.5)
    plt.title('Country Distribution Heatmap using Quartic Kernel Density Estimation')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')

    plt.axhline(y=0, color='k', linestyle='-', alpha=0.3)
    plt.axvline(x=0, color='k', linestyle='-', alpha=0.3)
    if os.path.exists('heatmap_graph.jpg'):
        os.remove('heatmap_graph.jpg')
    plt.savefig('heatmap_graph.jpg')
    plt.show()

    Image1 = cv2.imread('heatmap_graph.jpg')
    Image1 = cv2.cvtColor(Image1, cv2.COLOR_BGR2RGB)
    Image2 = cv2.imread('data/world.jpg')
    Image2 = cv2.cvtColor(Image2, cv2.COLOR_BGR2RGB)

    plt.subplot(1, 2, 1)
    plt.imshow(Image1)
    plt.title("Image 1")
    plt.subplot(1, 2, 2)
    plt.imshow(Image2)
    plt.title("Image 2")
    plt.show()

    Image1 = Image1[93:713, 173:1087]

    Image2_resized = cv2.resize(Image2, (Image1.shape[1], Image1.shape[0]))

    alpha = 0.7
    dst = cv2.addWeighted(Image1, alpha, Image2_resized, 1-alpha, 0)
    plt.imshow(dst)
    plt.title("Blended Image")
    if os.path.exists('HeatOnMap.jpg'):
        os.remove('HeatOnMap.jpg')
    plt.savefig('HeatOnMap.jpg')
    plt.show()

HeatOnMap()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 139
#     136     plt.savefig('HeatOnMap.jpg')
#     137     plt.show()
# --> 139 HeatOnMap()
#
# Cell In[16], line 21, in HeatOnMap()
#      20 def HeatOnMap():
# ---> 21     counties2 = Hcountries
#      23     country_counts = pd.Series(counties2).value_counts().reset_index()
#      24     country_counts.columns = ['country', 'count']
#
# NameError: name 'Hcountries' is not defined

# %% [markdown]
# 3D Graph

# %%
def find_title_length():
    global title_length
    title_length = []
    for i in range(len(list_of_items)):
        length = len(list_of_items[i][2])
        title_length.append(length)

# %%
def find_ThrD_prices():
    global ThrD_Price, ThrD_ShipPrice
    ThrD_Price = []
    ThrD_ShipPrice = []
    for i in range(len(list_of_items)):
        tempPrice = list_of_items[i][1].replace('$','').replace(',','')
        if 'to' not in tempPrice:
            tempPrice2 = float(list_of_items[i][1].replace('$','').replace(',',''))
        ThrD_Price.append(tempPrice2)
        tempPrice3 = list_of_items[i][5].replace('$','').replace(',','')
        if 'to' not in tempPrice3:
            tempPrice4 = float(list_of_items[i][5].replace('$','').replace(',',''))
        ThrD_ShipPrice.append(tempPrice4)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

def Show_3d_Graph(x, y, z, dist):
    find_ThrD_prices()
    find_title_length()
    fig = plt.figure(figsize=(14, 10))
    ax = fig.add_subplot(projection='3d')

    prices = np.array(ThrD_Price)
    ship_prices = np.array(ThrD_ShipPrice)
    title_lengths = np.array(title_length)

    avg_price = np.mean(prices)
    avg_ship_price = np.mean(ship_prices)
    avg_title_length = np.mean(title_lengths)

    distances = np.sqrt((prices - avg_price)**2 +
                        (ship_prices - avg_ship_price)**2 +
                        (title_lengths - avg_title_length)**2)

    neighbor_mask = distances < dist
    non_neighbor_mask = ~neighbor_mask

    neigh_price = prices[neighbor_mask]
    neigh_ship_price = ship_prices[neighbor_mask]
    neigh_title_length = title_lengths[neighbor_mask]

    new_price = prices[non_neighbor_mask]
    new_ship_price = ship_prices[non_neighbor_mask]
    new_title_length = title_lengths[non_neighbor_mask]

    ax.scatter(new_price, new_ship_price, new_title_length,
               c='blue', s=80, alpha=0.85, edgecolor='black', linewidth=0.5, label='Other Points')

    ax.scatter(neigh_price, neigh_ship_price, neigh_title_length,
               c='red', s=80, alpha=0.85, edgecolor='black', linewidth=0.5, label='Neighbor Points')

    ax.scatter(avg_price, avg_ship_price, avg_title_length,
               c='black', s=200, marker='*', label='Central Point')

    ax.set_xlabel('Price', fontsize=14, labelpad=12)
    ax.set_ylabel('Shipping Price', fontsize=14, labelpad=12)
    ax.set_zlabel('Title Length', fontsize=14, labelpad=20)

    ax.view_init(elev=30, azim=135)

    ax.legend()

    ax.grid(True, color='lightgray', linestyle='--', linewidth=0.7)
    ax.xaxis._axinfo['grid'].update(color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
    ax.yaxis._axinfo['grid'].update(color='gray', linestyle='--', linewidth=0.5, alpha=0.3)
    ax.zaxis._axinfo['grid'].update(color='gray', linestyle='--', linewidth=0.5, alpha=0.3)

    plt.title('3D Product Price Visualization', fontsize=18, pad=20)

    ax.view_init(x, y, z)
    plt.tight_layout()
    if os.path.exists('3D_Graph.jpg'):
        os.remove('3D_Graph.jpg')
    plt.savefig('3D_Graph.jpg', dpi=300, bbox_inches='tight')
    plt.show()


x10 = int(input("Enter X (elevation) angle: "))
y10 = int(input("Enter Y (azimuth) angle: "))
z10 = int(input("Enter Z (roll) angle: "))
dist = float(input("Enter distance: "))
Show_3d_Graph(x10, y10, z10, dist)

# %% [markdown]
# Photo Edit

# %%
import cv2
import matplotlib.pyplot as plt

ImageOption = int(input("choose an option: "))

imagePath = 'item_image.jpg'
image = cv2.imread(imagePath)
if ImageOption == 1:
    plt.imshow(image)
    plt.show()
elif ImageOption == 2:
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(imageRGB)
    plt.show()
elif ImageOption == 3:
    ImageGray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    plt.imshow(ImageGray, cmap='gray')
    plt.show()
elif ImageOption == 4:
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    brightness_lvl = int(input("choose the brightness level: "))
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            for k in range(image.shape[2]):
                image[i][j][k] = min(255, max(0, image[i][j][k] + brightness_lvl))
    plt.imshow(image)
    plt.show()
elif ImageOption == 5:
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            for k in range(image.shape[2]):
                image[i][j][k] = min(255, max(0, 255 - image[i][j][k]))
    plt.imshow(image)
    plt.show()
elif ImageOption == 6:
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)
    plt.imshow(edges, cmap='gray')
    plt.show()

# %% [markdown]
# More Graphs

# %%
def show_condition_graph():
    cond_name = [list(condition.keys())[0], 
                 list(condition.keys())[1], 
                 list(condition.keys())[2], 
                 list(condition.keys())[3], 
                 list(condition.keys())[4]]
    cond_value = [condition[cond_name[0]], 
                  condition[cond_name[1]], 
                  condition[cond_name[2]], 
                  condition[cond_name[3]], 
                  condition[cond_name[4]]]

    plt.figure(figsize=(10, 6))
    bars = plt.bar(cond_name, cond_value, alpha=0.85, color=plt.cm.Set2.colors, edgecolor='black')

    plt.xlabel('Condition', fontsize=12, labelpad=10)
    plt.ylabel('Count', fontsize=12, labelpad=10)
    plt.title('Condition Count', fontsize=16, pad=15)
    plt.xticks(rotation=45, fontsize=10)
    plt.yticks(fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.4)

    plt.tight_layout()

    if os.path.exists('condition_graph.jpg'):
        os.remove('condition_graph.jpg')
    plt.savefig('condition_graph.jpg', dpi=300, bbox_inches='tight')
    plt.show()

show_condition_graph()

# %%
import numpy as np

def show_price_graph(x, y):
    amount = []
    nor_value = []
    ship_value = []
    if y == 0:
        y = len(price) if len(price) < len(ship_price) else len(ship_price)
    for i in range(x, y):
        try:
            nor_value.append(float(price[i].get_text(strip=True).replace('$', '').replace(',', '')))
            ship_value.append(float(ship_price[i].get_text(strip=True).replace('$', '').replace(',', '').replace(' shipping', '')))
            amount.append(i)
        except:
            pass

    plt.figure(figsize=(12, 7))

    plt.plot(amount, nor_value, color="#E63946", linestyle="--", linewidth=3, marker="o", markersize=8, label="Item Price")
    plt.plot(amount, ship_value, color="#457B9D", linestyle=':', marker="s", markersize=6, linewidth=3, label="Shipping Price")

    plt.title("Price vs Shipping Price", fontsize=16, pad=15)
    plt.xlabel("Amount", fontsize=12, labelpad=10)
    plt.ylabel("Price", fontsize=12, labelpad=10)

    plt.legend(fontsize=12, loc='upper left', frameon=True, edgecolor='gray')
    plt.grid(axis='both', linestyle='--', alpha=0.5)

    plt.xticks(rotation=45, fontsize=10)
    plt.yticks(fontsize=10)

    plt.tight_layout()

    if os.path.exists('price_compare.jpg'):
        os.remove('price_compare.jpg')
    plt.savefig('price_compare.jpg', dpi=300, bbox_inches='tight')
    plt.show()

a = int(input("choose the amount of items you want to see: "))
b = int(input("choose the amount of items you want to see: "))
show_price_graph(a, b)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

def show_price_graph2(x, y):
    amount = []
    nor_price = []
    avr_price = []
    for i in range(x, y):
        try:
            nor_price.append(float(price[i].get_text(strip=True).replace('$', '').replace(',', '')))
            amount.append(i)
        except:
            pass

    if y <= 60 and x == 0:
        y = len(price) if len(price) < len(ship_price) else len(ship_price)
        y -= 1
    avr = sum(nor_price) / len(nor_price)
    for i in range(x, y):
        avr_price.append(avr)

    plt.figure(figsize=(14, 8), facecolor='#f9f9f9')

    plt.plot(amount, nor_price, color="#FF6F61", linestyle="-", linewidth=2.5,
             marker="D", markersize=9, markerfacecolor='white', markeredgewidth=2,
             label="Item Price")
    plt.plot(amount, avr_price, color="#3E92CC", linestyle='-.', linewidth=2.5,
             marker="^", markersize=8, markerfacecolor='lightblue', markeredgewidth=1.5,
             label="Average Price")

    for i in range(int(min(nor_price)), int(max(nor_price))+20, 20):
        plt.axhspan(i, i+10, facecolor='gray', alpha=0.05)

    plt.title("Price vs Shipping Price", fontsize=18, fontweight='bold', color='#333', pad=20)
    plt.xlabel("Amount", fontsize=14, labelpad=12)
    plt.ylabel("Price", fontsize=14, labelpad=12)

    plt.legend(fontsize=13, loc='upper left', frameon=True, facecolor='white', edgecolor='black')

    plt.grid(axis='both', linestyle=':', alpha=0.4, color='gray')

    plt.xticks(rotation=45, fontsize=11)
    plt.yticks(fontsize=11)

    plt.tight_layout()

    if os.path.exists('price_avr_compare.jpg'):
        os.remove('price_avr_compare.jpg')
    plt.savefig('price_avr_compare.jpg', dpi=300, bbox_inches='tight')
    plt.show()

a = int(input("choose the amount of items you want to see: "))
b = int(input("choose the amount of items you want to see: "))
show_price_graph2(a, b)

# %%
def show_seller_bargraph():
    seller_name = []
    seller_value = []
    for i in range(len(Sellers)):
        name = list(Sellers.keys())[i]
        if len(name) > 15:
            name = name[:12] + '...'
        seller_name.append(name)
        seller_value.append(Sellers[list(Sellers.keys())[i]])

    plt.figure(figsize=(12, 7))
    bars = plt.bar(seller_name, seller_value, alpha=0.85, color=plt.cm.Paired.colors, edgecolor='black')

    plt.xlabel('Seller', fontsize=12, labelpad=10)
    plt.ylabel('Count', fontsize=12, labelpad=10)
    plt.title('Number of Items per Seller', fontsize=16, pad=15)

    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.yticks(fontsize=10)

    plt.grid(axis='y', linestyle='--', alpha=0.4)

    plt.tight_layout()

    if os.path.exists('amountseller_graph.jpg'):
        os.remove('amountseller_graph.jpg')
    plt.savefig('amountseller_graph.jpg', dpi=300, bbox_inches='tight')
    plt.show()

show_seller_bargraph()

# %% [markdown]
# GUI code

# %%
import webbrowser
import PIL.ImageTk
import requests as rq
import os
import PIL
import cv2

#region ebay_win_functions
def update_scroll_item(c):
    global text_scroll, max_amount
    max_amount = len(list_of_items)
    text_scroll = str(c) + ' / ' + str(max_amount)
    return text_scroll

def item_next():
    global c1, text_scroll, Item_scroll, item_name, item_price
    if c1 < len(list_of_items) - 1:
        c1 += 1
        text_scroll = update_scroll_item(c1)
        Item_scroll.config(text=text_scroll)
        item_name.config(text=str(list_of_items[c1][2]))
        item_price.config(text=str(list_of_items[c1][1]))

def item_prev():
    global c1, text_scroll, Item_scroll, item_name, item_price
    if c1 > 0:
        c1 -= 1
        text_scroll = update_scroll_item(c1)
        Item_scroll.config(text=text_scroll)
        item_name.config(text=str(list_of_items[c1][2]))
        item_price.config(text=str(list_of_items[c1][1]))

def UpdateItems():
    item_name.config(text=str(list_of_items[c1][2]))
    item_price.config(text=str(list_of_items[c1][1]))
    Item_scroll.config(text=str(c1) + ' / ' + str(len(list_of_items)))

def Combo_Function1():
    Search_ebay(search_bar.get())
    UpdateItems()
#endregion

#region inspection_win_functions
def image_getter(c):
    if os.path.exists('item_image.jpg'):
        os.remove('item_image.jpg')
        img_url = list_of_items[c][4]
        response = requests.get(img_url)
        with open('item_image.jpg', 'wb') as handler:
            handler.write(response.content)
    else:
        img_url = list_of_items[c][4]
        response = requests.get(img_url)
        with open('item_image.jpg', 'wb') as handler:
            handler.write(response.content)

def show_Item_graph_win():
    show_Item_graph()
    img = PIL.Image.open('item_Graph.jpg')
    img = img.resize((600, 400))
    photo = PIL.ImageTk.PhotoImage(img)

    graphwin1 = Toplevel()
    graphwin1.geometry("700x500")
    graphwin1.title("Item Graph")
    graphwin1.config(bg="#2C3E50")

    title_label = Label(graphwin1,
                        text="Item Rating Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 18, 'bold'))
    title_label.place(relx=0.5, y=20, anchor='center')

    label4 = Label(graphwin1, image=photo, bg="#2C3E50")
    label4.image = photo
    label4.place(relx=0.5, rely=0.55, anchor='center')

def show_seller_graph_win():
    Show_seller_graph()
    img = PIL.Image.open('Seller_Graph.jpg') 
    img = img.resize((600, 400))
    photo = PIL.ImageTk.PhotoImage(img)

    graphwin2 = Toplevel()
    graphwin2.geometry("700x500")
    graphwin2.title("Seller Graph")
    graphwin2.config(bg="#2C3E50")

    title_label = Label(graphwin2,
                        text="Seller Rating Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 18, 'bold'))
    title_label.place(relx=0.5, y=20, anchor='center')

    label5 = Label(graphwin2, image=photo, bg="#2C3E50")
    label5.image = photo
    label5.place(relx=0.5, rely=0.55, anchor='center')
#endregion

#region Photo_edit_win_functions
def combo_function2():
    image_getter(c1)
    set_image()

def set_image():
    img = PIL.Image.open('item_image.jpg')
    img = img.resize((300, 300))
    photo = PIL.ImageTk.PhotoImage(img)
    img_label.config(image=photo)
    img_label.image = photo

def image_gray():
    img = cv2.imread('item_image.jpg')
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray_bgr = cv2.cvtColor(gray_img, cv2.COLOR_GRAY2BGR)
    cv2.imwrite('item_image.jpg', gray_bgr)
    set_image()

def image_brightness():
    img = cv2.imread('item_image.jpg')
    brightness_lvl = Brightness_Scroll.get()
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            for k in range(img.shape[2]):
                img[i][j][k] = min(255, max(0, img[i][j][k] + brightness_lvl))
    cv2.imwrite('item_image.jpg', img)
    set_image()

def image_negative():
    img = cv2.imread('item_image.jpg')
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            for k in range(img.shape[2]):
                img[i][j][k] = min(255, max(0, 255 - img[i][j][k]))
    cv2.imwrite('item_image.jpg', img)
    set_image()

def image_edge():
    img = cv2.imread('item_image.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 100, 200)
    cv2.imwrite('item_image.jpg', edges)
    set_image()

#endregion

#region Photo_edit_win
def photo_edit_win():
    global img_label, Brightness_Scroll
    img = PIL.Image.open('item_image.jpg') 
    img = img.resize((300, 300))
    photo = PIL.ImageTk.PhotoImage(img)

    image_win = Toplevel()
    image_win.geometry("960x540")
    image_win.title("Photo Editing")
    image_win.config(bg="#2C3E50")

    title_label = Label(image_win,
                        text="Photo Editing",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.place(relx=0.5, y=20, anchor='center')

    img_label = Label(image_win, image=photo, bg="#2C3E50")
    img_label.image = photo
    img_label.place(x=330, y=70)

    def create_button(text, command, x, y):
        btn = Button(image_win,
                     text=text,
                     command=command,
                     bg='#2980B9',
                     fg='white',
                     font=('Verdana', 12, 'bold'),
                     relief='raised', bd=4)
        btn.place(x=x, y=y)
        btn.bind("<Enter>", lambda e: btn.config(bg='#F39C12'))
        btn.bind("<Leave>", lambda e: btn.config(bg='#2980B9'))
        return btn

    Original_button = create_button("Original", combo_function2, 20, 270)
    Gray_button = create_button("Black & White", image_gray, 20, 320)
    Brightness_button = create_button("Change Brightness", image_brightness, 20, 370)
    Negative_button = create_button("Negative", image_negative, 20, 420)
    Edge_button = create_button("Edge Detection", image_edge, 20, 470)

    Brightness_Scroll = Scale(image_win,
                              from_=-200,
                              to=200,
                              orient=HORIZONTAL,
                              bg='#34495E',
                              fg='white',
                              length=350,
                              font=('Verdana', 10, 'bold'),
                              relief='flat',
                              highlightthickness=0)
    Brightness_Scroll.place(x=300, y=360)
#endregion

#region Inspection_win
def inspectionWin():
    global c1, insp_win, Graph1_button, Graph2_button
    #item_rate(c1)  # <--------------------------- Remove to Activate (read report for understanding)
    #seller_rate(c1)    # <--------------------------- Remove to Activate (read report for understanding)
    image_getter(c1)
    img = PIL.Image.open('item_image.jpg')
    img = img.resize((300, 300))
    photo = PIL.ImageTk.PhotoImage(img)

    try:
        item_rate = (f'Five star rating: {five_rate_count}\n'
                     f'Four star rating: {four_rate_count}\n'
                     f'Three star rating: {three_rate_count}\n'
                     f'Two star rating: {two_rate_count}\n'
                     f'One star rating: {one_rate_count}')
        item_rate_found = True
    except:
        item_rate = ('Five star rating: not available\n'
                     'Four star rating: not available\n'
                     'Three star rating: not available\n'
                     'Two star rating: not available\n'
                     'One star rating: not available')
        item_rate_found = False

    try:
        seller_rate = (f'Accurate description: {acc_rate}\n'
                       f'Shipping cost: {ship_cost}\n'
                       f'Shipping speed: {ship_speed}\n'
                       f'Customer service: {comm}')
        Seller_rate_found = True
    except:
        seller_rate = ('Accurate description: not available\n'
                       'Shipping cost: not available\n'
                       'Shipping speed: not available\n'
                       'Customer service: not available')
        Seller_rate_found = False

    insp_win = Toplevel()
    insp_win.geometry("960x540")
    insp_win.title("Ebay Inspection")
    insp_win.config(bg="#2C3E50")
    insp_win.protocol("WM_DELETE_WINDOW", on_inspect_close)

    title_label = Label(insp_win,
                        text="Item Inspection",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.place(relx=0.5, y=20, anchor='center')

    label = Label(insp_win, image=photo, bg="#2C3E50")
    label.image = photo
    label.place(x=30, y=70)

    label2 = Label(insp_win,
                   text=list_of_items[c1][2],
                   bg='#34495E',
                   fg='white',
                   font=('Verdana', 12, 'bold'),
                   wraplength=250,
                   justify='left')
    label2.place(x=30, y=380)

    label3 = Label(insp_win,
                   text=list_of_items[c1][1],
                   bg='#34495E',
                   fg='white',
                   font=('Verdana', 12),
                   wraplength=250,
                   justify='left')
    label3.place(x=30, y=480)

    label4 = Label(insp_win,
                   text=item_rate,
                   bg='#34495E',
                   fg='white',
                   font=('Verdana', 10),
                   justify='left')
    label4.place(x=400, y=70)

    label5 = Label(insp_win,
                   text=seller_rate,
                   bg='#34495E',
                   fg='white',
                   font=('Verdana', 10),
                   justify='left')
    label5.place(x=400, y=200)

    Graph1_button = Button(insp_win,
                           state=NORMAL if item_rate_found else DISABLED,
                           text="Show Item Graph",
                           command=show_Item_graph_win,
                           bg='#2980B9',
                           fg='white',
                           font=('Verdana', 12, 'bold'),
                           relief='raised', bd=4)
    Graph1_button.place(x=400, y=350)
    Graph1_button.bind("<Enter>", lambda e: Graph1_button.config(bg='#F39C12'))
    Graph1_button.bind("<Leave>", lambda e: Graph1_button.config(bg='#2980B9'))

    Graph2_button = Button(insp_win,
                           state=NORMAL if Seller_rate_found else DISABLED,
                           text="Show Seller Graph",
                           command=show_seller_graph_win,
                           bg='#2980B9',
                           fg='white',
                           font=('Verdana', 12, 'bold'),
                           relief='raised', bd=4)
    Graph2_button.place(x=400, y=400)
    Graph2_button.bind("<Enter>", lambda e: Graph2_button.config(bg='#F39C12'))
    Graph2_button.bind("<Leave>", lambda e: Graph2_button.config(bg='#2980B9'))

    Photo_edit_button = Button(insp_win,
                               text="Edit Photo",
                               command=photo_edit_win,
                               bg='#2980B9',
                               fg='white',
                               font=('Verdana', 12, 'bold'),
                               relief='raised', bd=4)
    Photo_edit_button.place(x=400, y=450)
    Photo_edit_button.bind("<Enter>", lambda e: Photo_edit_button.config(bg='#F39C12'))
    Photo_edit_button.bind("<Leave>", lambda e: Photo_edit_button.config(bg='#2980B9'))

def on_inspect_close():
    global insp_win
    insp_win.destroy()
    insp_win = None
    insp_win.config(state=NORMAL)
#endregion

#region Networkx_win
def netx_function():
    networkx_graph(int(Low_numx.get()), int(Max_numx.get()), int(Diff_numx.get()))
    img = PIL.Image.open('NetX_Graph.jpg')
    img = img.resize((350, 350))
    photo = PIL.ImageTk.PhotoImage(img)
    nex_label.config(image=photo)
    nex_label.image = photo

def netx_win():
    global netx_win, Low_numx, Max_numx, Diff_numx, nex_label
    img = PIL.Image.open('NetX_Graph.jpg')
    img = img.resize((350, 350))
    photo = PIL.ImageTk.PhotoImage(img)

    netx_win = Toplevel()
    netx_win.geometry("960x540")
    netx_win.title("NetworkX")
    netx_win.config(bg="#2C3E50") 

    title_label = Label(netx_win,
                        text="NetworkX Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.place(relx=0.5, y=30, anchor='center')

    nex_label = Label(netx_win, image=photo, bg="#2C3E50")
    nex_label.image = photo
    nex_label.place(x=300, y=70)

    Low_lbl = Label(netx_win,
                    text='Low Num Set',
                    bg='#2C3E50',
                    fg='white',
                    font=('Verdana', 12, 'bold'))
    Low_lbl.place(x=50, y=430)

    high_lbl = Label(netx_win,
                     text='High Num Set',
                     bg='#2C3E50',
                     fg='white',
                     font=('Verdana', 12, 'bold'))
    high_lbl.place(x=50, y=470)

    diff_lbl = Label(netx_win,
                     text='Diff Num Set',
                     bg='#2C3E50',
                     fg='white',
                     font=('Verdana', 12, 'bold'))
    diff_lbl.place(x=50, y=510)

    warning_label = Label(netx_win,
                          text="⚠ Warning: Make sure Low Num doesn't exceed High Num",
                          bg='#2C3E50',
                          fg='red',
                          font=('Verdana', 10, 'bold'))
    warning_label.place(x=400, y=500)

    Low_numx = Scale(netx_win,
                     from_=0,
                     to=max_amount,
                     orient=HORIZONTAL,
                     bg='#34495E',
                     fg='white',
                     troughcolor='#2980B9',
                     length=300)
    Low_numx.place(x=200, y=420)

    Max_numx = Scale(netx_win,
                     from_=0,
                     to=max_amount,
                     orient=HORIZONTAL,
                     bg='#34495E',
                     fg='white',
                     troughcolor='#2980B9',
                     length=300)
    Max_numx.place(x=200, y=460)

    Diff_numx = Entry(netx_win,
                      bg='#ECF0F1',
                      font=('Verdana', 12),
                      relief='groove', bd=3)
    Diff_numx.place(x=200, y=500, width=200)

    submit_nex = Button(netx_win,
                        text="Submit",
                        bg='#2980B9',
                        fg='white',
                        font=('Verdana', 12, 'bold'),
                        relief='raised', bd=4,
                        padx=10, pady=5,
                        command=netx_function)
    submit_nex.place(x=700, y=440)
    submit_nex.bind("<Enter>", lambda e: submit_nex.config(bg='#F39C12'))
    submit_nex.bind("<Leave>", lambda e: submit_nex.config(bg='#2980B9'))
#endregion

#region Graph_wins
def condition_graph_win():
    #get_condition()   # <--------------------------- Remove to Activate (read report for understanding)
    show_condition_graph()
    img = PIL.Image.open('condition_graph.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)

    conGraph_win = Toplevel()
    conGraph_win.geometry("540x540")
    conGraph_win.title("Condition Graph")
    conGraph_win.config(bg="#2C3E50") 

    title_label = Label(conGraph_win,
                        text="Condition Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.pack(pady=10)

    conGraph_label = Label(conGraph_win,
                           image=photo,
                           bg="#2C3E50")
    conGraph_label.image = photo
    conGraph_label.place(x=20, y=60)

    frame = Frame(conGraph_win, bg='white', bd=2, relief='solid')
    frame.place(x=18, y=58, width=504, height=454)
    conGraph_label.lift()

def edit_prComp_graph():
    show_price_graph(int(prComp_entry.get()), int(prComp_entry2.get()))
    img = PIL.Image.open('price_compare.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)
    prComp_label.config(image=photo)
    prComp_label.image = photo

def price_graph_win():
    global prComp_entry, prComp_label, prComp_entry2
    show_price_graph(0, 60)
    img = PIL.Image.open('price_compare.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)

    prComp_win = Toplevel()
    prComp_win.geometry("960x540")
    prComp_win.title("Price Compare")
    prComp_win.config(bg="#34495E")

    title_label = Label(prComp_win,
                        text="Price Compare Graph",
                        bg="#34495E",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.pack(pady=10)

    prComp_label = Label(prComp_win, image=photo, bg="#34495E")
    prComp_label.image = photo
    prComp_label.place(x=20, y=60)

    prComp_label2 = Label(prComp_win,
                          text="First Number of Items:",
                          bg='#2C3E50',
                          fg='white',
                          font=('Verdana', 12, 'bold'),
                          padx=10, pady=5)
    prComp_label2.place(x=600, y=90)

    prComp_entry = Entry(prComp_win,
                         bg='#ECF0F1',
                         font=('Verdana', 12),
                         relief='groove', bd=3)
    prComp_entry.place(x=600, y=130, width=200)

    prComp_label3 = Label(prComp_win,
                          text="Last Number of Items:",
                          bg='#2C3E50',
                          fg='white',
                          font=('Verdana', 12, 'bold'),
                          padx=10, pady=5)
    prComp_label3.place(x=600, y=180)

    prComp_entry2 = Entry(prComp_win,
                          bg='#ECF0F1',
                          font=('Verdana', 12),
                          relief='groove', bd=3)
    prComp_entry2.place(x=600, y=220, width=200)

    prComp_button = Button(prComp_win,
                           text="Submit",
                           bg='#2980B9',
                           fg='white',
                           font=('Verdana', 12, 'bold'),
                           relief='raised', bd=4,
                           padx=10, pady=5,
                           command=edit_prComp_graph)
    prComp_button.place(x=700, y=280)
    prComp_button.bind("<Enter>", lambda e: prComp_button.config(bg='#F39C12'))
    prComp_button.bind("<Leave>", lambda e: prComp_button.config(bg='#2980B9'))

def edit_prComp_graph2():
    show_price_graph2(int(prComp_entry3.get()), int(prComp_entry4.get()))
    img = PIL.Image.open('price_avr_compare.jpg')
    img = img.resize((500, 450)) 
    photo = PIL.ImageTk.PhotoImage(img)
    prComp_labelw.config(image=photo)
    prComp_labelw.image = photo

def price_graph_win2():
    global prComp_entry3, prComp_labelw, prComp_entry4
    show_price_graph2(0, 60)
    img = PIL.Image.open('price_avr_compare.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)

    prComp_win2 = Toplevel()
    prComp_win2.geometry("960x540")
    prComp_win2.title("Price Average Compare")
    prComp_win2.config(bg="#34495E")

    title_label = Label(prComp_win2,
                        text="Price/Average Compare Graph",
                        bg="#34495E",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.pack(pady=10)

    prComp_labelw = Label(prComp_win2, image=photo, bg="#34495E")
    prComp_labelw.image = photo
    prComp_labelw.place(x=20, y=60)

    prComp_label2 = Label(prComp_win2,
                          text="First Number of Items:",
                          bg='#2C3E50',
                          fg='white',
                          font=('Verdana', 12, 'bold'),
                          padx=10, pady=5)
    prComp_label2.place(x=600, y=90)

    prComp_entry3 = Entry(prComp_win2,
                          bg='#ECF0F1',
                          font=('Verdana', 12),
                          relief='groove', bd=3)
    prComp_entry3.place(x=600, y=130, width=200)

    prComp_label3 = Label(prComp_win2,
                          text="Last Number of Items:",
                          bg='#2C3E50',
                          fg='white',
                          font=('Verdana', 12, 'bold'),
                          padx=10, pady=5)
    prComp_label3.place(x=600, y=180)

    prComp_entry4 = Entry(prComp_win2,
                          bg='#ECF0F1',
                          font=('Verdana', 12),
                          relief='groove', bd=3)
    prComp_entry4.place(x=600, y=220, width=200)

    prComp_button2 = Button(prComp_win2,
                            text="Submit",
                            bg='#2980B9',
                            fg='white',
                            font=('Verdana', 12, 'bold'),
                            relief='raised', bd=4,
                            padx=10, pady=5,
                            command=edit_prComp_graph2)
    prComp_button2.place(x=700, y=280)
    prComp_button2.bind("<Enter>", lambda e: prComp_button2.config(bg='#F39C12'))
    prComp_button2.bind("<Leave>", lambda e: prComp_button2.config(bg='#2980B9'))

def amount_seller_Graph():
    #get_sellers()   # <--------------------------- Remove to Activate (read report for understanding)
    show_seller_bargraph()
    img = PIL.Image.open('amountseller_graph.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)

    amoSeller_win = Toplevel()
    amoSeller_win.geometry("540x540")
    amoSeller_win.title("Amount of Sellers Graph")
    amoSeller_win.config(bg="#2C3E50")

    title_label = Label(amoSeller_win,
                        text="Amount of Sellers Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.pack(pady=10)

    amoSeller_label = Label(amoSeller_win,
                            image=photo,
                            bg="#2C3E50")
    amoSeller_label.image = photo
    amoSeller_label.place(x=20, y=60) 

    frame = Frame(amoSeller_win, bg='white', bd=2, relief='solid')
    frame.place(x=18, y=58, width=504, height=454)
    amoSeller_label.lift()

def HeatOnMap_graph_win():
    # get_Country() # <--------------------------- Remove to Activate (read report for understanding)
    HeatOnMap()
    img = PIL.Image.open('HeatOnMap.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)

    HeatOnMap_win = Toplevel()
    HeatOnMap_win.geometry("540x540")
    HeatOnMap_win.title("HeatMap Graph")
    HeatOnMap_win.config(bg="#2C3E50") 

    title_label = Label(HeatOnMap_win,
                        text="HeatMap Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.place(relx=0.5, y=30, anchor='center')

    HeatOnMap_label = Label(HeatOnMap_win, image=photo, bg="#2C3E50")
    HeatOnMap_label.image = photo
    HeatOnMap_label.place(x=20, y=70)

def ThrD_functions():
    if neighbor_entry.get() == '':
        Show_3d_Graph(x_axis_scroll.get(), y_axis_scroll.get(), z_axis_scroll.get(), 0)
    else:
        Show_3d_Graph(x_axis_scroll.get(), y_axis_scroll.get(), z_axis_scroll.get(), int(neighbor_entry.get()))
    img = PIL.Image.open('3D_Graph.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)
    ThrD_label.config(image=photo)
    ThrD_label.image = photo

def ThrD_win():
    global ThrD_label, x_axis_scroll, y_axis_scroll, z_axis_scroll, neighbor_entry
    Show_3d_Graph(30, 30, 0, 0)
    img = PIL.Image.open('3D_Graph.jpg')
    img = img.resize((500, 450))
    photo = PIL.ImageTk.PhotoImage(img)

    ThrD_win = Toplevel()
    ThrD_win.geometry("960x540")
    ThrD_win.title("3D Graph")
    ThrD_win.config(bg="#2C3E50")

    title_label = Label(ThrD_win,
                        text="3D Graph",
                        bg="#2C3E50",
                        fg="white",
                        font=('Verdana', 20, 'bold'))
    title_label.place(relx=0.5, y=30, anchor='center')

    ThrD_label = Label(ThrD_win, image=photo, bg="#2C3E50")
    ThrD_label.image = photo
    ThrD_label.place(x=20, y=70)

    submit_button = Button(ThrD_win,
                           text="Submit",
                           bg='#2980B9',
                           fg='white',
                           font=('Verdana', 12, 'bold'),
                           relief='raised', bd=4,
                           padx=10, pady=5,
                           command=ThrD_functions)
    submit_button.place(x=700, y=450)

    x_axis_label = Label(ThrD_win,
                         text="Choose the x-axis view:",
                         bg='#2C3E50',
                         fg='white',
                         font=('Verdana', 12, 'bold'))
    x_axis_label.place(x=550, y=70)

    x_axis_scroll = Scale(ThrD_win,
                          from_=0,
                          to=180,
                          orient=HORIZONTAL,
                          bg='#34495E',
                          fg='white',
                          troughcolor='#2980B9',
                          length=350)
    x_axis_scroll.place(x=550, y=100)

    y_axis_label = Label(ThrD_win,
                         text="Choose the y-axis view:",
                         bg='#2C3E50',
                         fg='white',
                         font=('Verdana', 12, 'bold'))
    y_axis_label.place(x=550, y=170)

    y_axis_scroll = Scale(ThrD_win,
                          from_=0,
                          to=180,
                          orient=HORIZONTAL,
                          bg='#34495E',
                          fg='white',
                          troughcolor='#2980B9',
                          length=350)
    y_axis_scroll.place(x=550, y=200)

    z_axis_label = Label(ThrD_win,
                         text="Choose the z-axis view:",
                         bg='#2C3E50',
                         fg='white',
                         font=('Verdana', 12, 'bold'))
    z_axis_label.place(x=550, y=270)

    z_axis_scroll = Scale(ThrD_win,
                          from_=0,
                          to=180,
                          orient=HORIZONTAL,
                          bg='#34495E',
                          fg='white',
                          troughcolor='#2980B9',
                          length=350)
    z_axis_scroll.place(x=550, y=300)

    neighbor_label = Label(ThrD_win,
                         text="Enter neighbor distance:",
                         bg='#2C3E50',
                         fg='white',
                         font=('Verdana', 12, 'bold'))
    neighbor_label.place(x=550, y=340)

    neighbor_entry = Entry(ThrD_win,
                         bg='#ECF0F1',
                         font=('Verdana', 12),
                         relief='groove', bd=3)
    neighbor_entry.place(x=550, y=370)
#endregion

#region ebay_win
def ebayWin():
    global c1, text_scroll, Item_scroll, item_name, item_price, search_bar
    c1 = 0
    text_scroll = update_scroll_item(c1)
    item_name_scroll = str(list_of_items[c1][2])
    item_price_scroll = str(list_of_items[c1][1]) 

    win.destroy()
    ebay_win = Tk()
    ebay_win.geometry("960x540")
    ebay_win.title("Ebay")
    ebay_win.config(bg="#34495E")

    label2 = Label(ebay_win,
                   text='Ebay Window',
                   bg='#34495E',
                   fg='white',
                   font=('Verdana', 28, 'bold'))
    label2.place(relx=0.5, y=50, anchor='center')

    item_name = Label(ebay_win,
                      text=item_name_scroll,
                      bg='#2C3E50',
                      fg='white',
                      font=('Verdana', 16, 'bold'),
                      padx=10, pady=5)
    item_name.place(x=50, y=250)

    item_price = Label(ebay_win,
                       text=item_price_scroll,
                       bg='#2C3E50',
                       fg='white',
                       font=('Verdana', 16, 'bold'),
                       padx=10, pady=5)
    item_price.place(x=310, y=300)

    Item_scroll = Label(ebay_win,
                        text=text_scroll,
                        bg='#2C3E50',
                        fg='white',
                        font=('Verdana', 15),
                        padx=10, pady=5)
    Item_scroll.place(x=450, y=200)

    search_bar = Entry(ebay_win,
                       bg='#ECF0F1',
                       fg='#2C3E50',
                       font=('Verdana', 15),
                       relief='groove',
                       bd=4)
    search_bar.place(x=350, y=150, width=250)

    def create_button(text, command, x, y, width=20):
        btn = Button(ebay_win,
                     text=text,
                     command=command,
                     bg='#2980B9',
                     fg='white',
                     activeforeground='white',
                     font=('Verdana', 12, 'bold'),
                     relief='raised',
                     bd=4,
                     padx=10,
                     pady=5,
                     width=width,
                     highlightthickness=0)
        btn.place(x=x, y=y)
        return btn
    create_button("Price/average Compare Graph", price_graph_win2, 400, 410, 25)
    create_button("3DGraph", ThrD_win, 220, 410, 12)
    create_button("HeatMap Graph", HeatOnMap_graph_win, 20, 410, 15)
    create_button("Amount of Sellers Graph", amount_seller_Graph, 620, 470, 22)
    create_button("Price Compare Graph", price_graph_win, 380, 470, 18)
    create_button("Condition Graph", condition_graph_win, 170, 470, 15)
    create_button("NetworkX", netx_win, 20, 470, 10)
    create_button("Search", lambda: Combo_Function1(), 600, 145, 10)
    create_button("Link", lambda: webbrowser.open(list_of_items[c1][3]), 450, 300, 10)
    create_button("Inspect", inspectionWin, 610, 300, 10)
    create_button(">", item_next, 550, 200, 3)
    create_button("<", item_prev, 370, 200, 3)

    ebay_win.update_idletasks()
    screen_width = ebay_win.winfo_screenwidth()
    screen_height = ebay_win.winfo_screenheight()
    x = (screen_width // 2) - (960 // 2)
    y = (screen_height // 2) - (540 // 2)
    ebay_win.geometry(f"+{x}+{y}")

    ebay_win.mainloop()
#endregion

#region Main_first_win
from tkinter import *

def on_enter(e):
    if e.widget.winfo_exists():
        ebaymarket['background'] = '#16A085'
        ebaymarket['bd'] = 3

def on_leave(e):
    if e.widget.winfo_exists():
        ebaymarket['background'] = '#1ABC9C'
        ebaymarket['bd'] = 2

win = Tk()
win.geometry("500x500")
win.title("Item Inspection")
win.config(bg="#2C3E50")

label1 = Label(win,
               text='Choose a Market:',
               bg="#2C3E50",
               fg="white",
               font=('Helvetica', 20, 'bold'))
label1.place(relx=0.5, y=70, anchor='center')

ebaymarket = Button(win,
                    text="Ebay",
                    command=ebayWin,
                    bg="#1ABC9C", 
                    fg="white",
                    activeforeground="white",
                    font=('Helvetica', 16, 'bold'),
                    relief="solid",
                    bd=2,
                    padx=20,
                    pady=10)
ebaymarket.place(relx=0.5, y=150, anchor='center')

ebaymarket.bind("<Enter>", on_enter)
ebaymarket.bind("<Leave>", on_leave)

win.update_idletasks()
screen_width = win.winfo_screenwidth()
screen_height = win.winfo_screenheight()
x = (screen_width // 2) - (500 // 2)
y = (screen_height // 2) - (500 // 2)
win.geometry(f"+{x}+{y}")

win.mainloop()
#endregion
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\omara\anaconda3\Lib\tkinter\__init__.py", line 1968, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\omara\AppData\Local\Temp\ipykernel_13348\2343816312.py", line 332, in on_inspect_close
#     insp_win.config(state=NORMAL)
#     ^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'config'

# %%
#include <iostream>
using namespace std;

void countCalls() {
    static int count = 0;  // Keeps its value between calls
    count++;
    cout << "Called " << count << " times\n";
}

int main() {
    countCalls();  // Called 1 times
    countCalls();  // Called 2 times
    countCalls();  // Called 3 times
    return 0;
}
